# %% [markdown]
# ### Importing Libraries

# %%
#Required libraries for the program

import pandas as pd
import json
import os
import psycopg2

# %% [markdown]
# ### Data Extract
# #### cloning data from git ---> phonepe/pulse
# #### data transformation----> dataframe creation from cloned pulse data

# %% [markdown]
# #####  Df1 aggregated_transaction

# %%
#to extract data from aggreagted---->transaction
#This is to direct the path to get the data as states from aggragated---transaction

path_1="C:/Users/Admin/Desktop/myproject/pulse/data/aggregated/transaction/country/india/state/"
agg_state_list=os.listdir(path_1)
agg_state_list

columns_trans={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in agg_state_list:
    state_path=path_1+state+"/"
    agg_year=os.listdir(state_path)
    for year in agg_year:
        year_path=state_path+year+"/"
        agg_year_list=os.listdir(year_path)
        for j_file in agg_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D1=json.load(Data)
            #print(D1)
            for data in D1['data']['transactionData']:
              Name=data['name']
              count=data['paymentInstruments'][0]['count']
              amount=data['paymentInstruments'][0]['amount']
              columns_trans['Transaction_type'].append(Name)
              columns_trans['Transaction_count'].append(count)
              columns_trans['Transaction_amount'].append(amount)
              columns_trans['State'].append(state)
              columns_trans['Year'].append(year)
              columns_trans['Quater'].append(int(j_file.strip('.json')))
#Succesfully created a dataframe
agg_transaction=pd.DataFrame(columns_trans)

# %%
agg_transaction.shape
# Out:
# (4314, 6)

# %% [markdown]
# #### Df2 aggregated_user

# %%
#to extract data from aggreagted---->user
#This is to direct the path to get the data as states from aggragated---user
columns_user={'State':[], 'Year':[],'Quater':[],'Brands':[], 'Transaction_count':[],"percentage":[]}


path_2="C:/Users/Admin/Desktop/myproject/pulse/data/aggregated/user/country/india/state/"
for state in agg_state_list:
    state_path=path_2+state+"/"
    agg_year=os.listdir(state_path)
    for year in agg_year:
        year_path=state_path+year+"/"
        agg_year_list=os.listdir(year_path)
        for j_file in agg_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D2=json.load(Data)
            #print(D2)
            try:
                for data in D2['data']['usersByDevice']:
                    Brand=data['brand']
                    Count=data['count']
                    Percentage=data['percentage']
                    columns_user['Brands'].append(Brand)
                    columns_user['Transaction_count'].append(Count)
                    columns_user['percentage'].append(Percentage)
                    columns_user['State'].append(state)
                    columns_user['Year'].append(year)
                    columns_user['Quater'].append(int(j_file.strip('.json')))
            except:
                pass
#Succesfully created a dataframe
agg_user=pd.DataFrame(columns_user)

# %%
agg_user.shape
# Out:
# (6732, 6)

# %% [markdown]
# #### Df3 aggregated_insurance

# %%
#to extract data from aggreagted---->insurance
#This is to direct the path to get the data as states from aggragated---insurance
columns_ins={'State':[], 'Year':[],'Quater':[],'Name':[], 'Count':[],"Insurance_Amount":[]}


path_3="C:/Users/Admin/Desktop/myproject/pulse/data/aggregated/insurance/country/india/state/"
agg_state_list=os.listdir(path_3)
agg_state_list
for state in agg_state_list:
    state_path=path_3+state+"/"
    agg_year=os.listdir(state_path)
    for year in agg_year:
        year_path=state_path+year+"/"
        agg_year_list=os.listdir(year_path)
        for j_file in agg_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D3=json.load(Data)
            #print(D3)
            
            try:
                for data in D3['data']['transactionData']:
                    #print(data)
                    name=data['name']
                    Count=data['paymentInstruments'][0]['count']
                    Amount=data['paymentInstruments'][0]['amount']
                    columns_ins['Name'].append(name)
                    columns_ins['Count'].append(Count)
                    columns_ins['Insurance_Amount'].append(Amount)
                    columns_ins['State'].append(state)
                    columns_ins['Year'].append(year)
                    columns_ins['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
        
#Succesfully created a dataframe
agg_insurance=pd.DataFrame(columns_ins)

# %%
agg_insurance.shape
# Out:
# (538, 6)

# %% [markdown]
# #### Df4 map_transaction

# %%
#to extract data from map---->transaction
#This is to direct the path to get the data as states from map---transaction

path_4="C:/Users/Admin/Desktop/myproject/pulse/data/map/transaction/hover/country/india/state/"
map_trans_list=os.listdir(path_4)
map_trans_list

col_m_t={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transaction_count':[],"Transaction_amount":[]}

for state in map_trans_list:
    state_path=path_4+state+"/"
    map_year=os.listdir(state_path)
    for year in map_year:
        year_path=state_path+year+"/"
        map_year_list=os.listdir(year_path)
        for j_file in map_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D4=json.load(Data)
            #print(D4)
            try:
                for data in D4['data']['hoverDataList']:
                    name=data['name']
                    Count=data['metric'][0]['count']
                    amount=data['metric'][0]['amount']
                    col_m_t['Districts'].append(name)
                    col_m_t['Transaction_count'].append(Count)
                    col_m_t['Transaction_amount'].append(amount)
                    col_m_t['State'].append(state)
                    col_m_t['Year'].append(year)
                    col_m_t['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
#Succesfully created a dataframe
map_trans=pd.DataFrame(col_m_t)

# %%
map_trans.shape
# Out:
# (17564, 6)

# %% [markdown]
# #### df5 map_user

# %%
#to extract data from map---->user
#This is to direct the path to get the data as states from map---user

path_5="C:/Users/Admin/Desktop/myproject/pulse/data/map/user/hover/country/india/state/"
map_user_list=os.listdir(path_5)
map_user_list

col_m_u={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Registered_Users':[],"app_opens":[]}

for state in map_user_list:
    state_path=path_5+state+"/"
    map_year=os.listdir(state_path)
    for year in map_year:
        year_path=state_path+year+"/"
        map_year_list=os.listdir(year_path)
        for j_file in map_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D5=json.load(Data)
            #print(D5)
            try:
                for data in D5['data']['hoverData'].items():
                    district=data[0]
                    registereduser=data[1]['registeredUsers']
                    appOpens=data[1]['appOpens']
                    col_m_u['Districts'].append(district)
                    col_m_u['Registered_Users'].append(registereduser)
                    col_m_u['app_opens'].append(appOpens)
                    col_m_u['State'].append(state)
                    col_m_u['Year'].append(year)
                    col_m_u['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
#Succesfully created a dataframe
map_user=pd.DataFrame(col_m_u)

# %%
map_user.shape
# Out:
# (17568, 6)

# %% [markdown]
# #### df6 map_insurance

# %%
#to extract data from map---->insurance
#This is to direct the path to get the data as states from map---insurance

path_6="C:/Users/Admin/Desktop/myproject/pulse/data/map/insurance/hover/country/india/state/"
map_ins_list=os.listdir(path_6)
map_ins_list

col_m_i={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transaction_count':[],"Transaction_amount":[]}

for state in map_ins_list:
    state_path=path_6+state+"/"
    map_year=os.listdir(state_path)
    for year in map_year:
        year_path=state_path+year+"/"
        map_year_list=os.listdir(year_path)
        for j_file in map_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D6=json.load(Data)
            print(D6)
            try:
                for data in D6['data']['hoverDataList']:
                    name=data['name']
                    Count=data['metric'][0]['count']
                    amount=data['metric'][0]['amount']
                    col_m_i['Districts'].append(name)
                    col_m_i['Transaction_count'].append(Count)
                    col_m_i['Transaction_amount'].append(amount)
                    col_m_i['State'].append(state)
                    col_m_i['Year'].append(year)
                    col_m_i['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
#Succesfully created a dataframe
map_ins=pd.DataFrame(col_m_i)
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 795.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 565.0}]}]}, 'responseTimestamp': 1692610808730}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 281.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 35, 'amount': 13651.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 1448.0}]}]}, 'responseTimestamp': 1692610860110}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 17734.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 109, 'amount': 137494.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2747.0}]}]}, 'responseTimestamp': 1692610913103}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 63978.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 164, 'amount': 167044.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 13244.0}]}]}, 'responseTimestamp': 1692610964959}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 28, 'amount': 45311.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 105, 'amount': 121104.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 15089.0}]}]}, 'responseTimestamp': 1692611017369}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 33, 'amount': 50997.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 182, 'amount': 223699.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 30539.0}]}]}, 'responseTimestamp': 1692611069370}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 81, 'amount': 182061.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 632, 'amount': 800758.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 44, 'amount': 73561.0}]}]}, 'responseTimestamp': 1692611120780}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 85229.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 692, 'amount': 982206.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 28, 'amount': 63852.0}]}]}, 'responseTimestamp': 1692611172361}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 45, 'amount': 90403.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 430, 'amount': 633029.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 26, 'amount': 56308.0}]}]}, 'responseTimestamp': 1692611223618}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 70, 'amount': 129013.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 535, 'amount': 687813.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 38, 'amount': 85640.0}]}]}, 'responseTimestamp': 1692611275241}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 112, 'amount': 224198.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 750, 'amount': 1114857.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 39, 'amount': 102155.0}]}]}, 'responseTimestamp': 1692611327083}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 85, 'amount': 178969.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 872, 'amount': 1172083.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 47, 'amount': 88146.0}]}]}, 'responseTimestamp': 1692619172137}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 56, 'amount': 109742.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 670, 'amount': 1060976.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 42, 'amount': 62677.0}]}]}, 'responseTimestamp': 1692619353838}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 77, 'amount': 133536.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 682, 'amount': 1052324.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 36, 'amount': 65285.0}]}]}, 'responseTimestamp': 1697612192136}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'north and middle andaman district', 'metric': [{'type': 'TOTAL', 'count': 95, 'amount': 156995.0}]}, {'name': 'south andaman district', 'metric': [{'type': 'TOTAL', 'count': 1006, 'amount': 1504528.0}]}, {'name': 'nicobars district', 'metric': [{'type': 'TOTAL', 'count': 44, 'amount': 96298.0}]}]}, 'responseTimestamp': 1706092848088}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 1913, 'amount': 352220.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 536, 'amount': 107046.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 931, 'amount': 176423.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 893, 'amount': 166029.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 3504, 'amount': 614212.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 847, 'amount': 161709.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2739, 'amount': 485777.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1978, 'amount': 343002.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1074, 'amount': 202289.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 825, 'amount': 158720.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2228, 'amount': 395099.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 1938, 'amount': 344326.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 2698, 'amount': 475539.0}]}]}, 'responseTimestamp': 1692610800738}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 3783, 'amount': 970549.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1535, 'amount': 383049.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 5509, 'amount': 1259159.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 2999, 'amount': 691281.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 7906, 'amount': 1892376.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 2565, 'amount': 722751.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2911, 'amount': 764850.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 3397, 'amount': 847519.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2543, 'amount': 696749.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 3493, 'amount': 841970.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 4422, 'amount': 1178762.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4230, 'amount': 1083584.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 4519, 'amount': 1093882.0}]}]}, 'responseTimestamp': 1692610852197}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 1965, 'amount': 1355741.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 811, 'amount': 546440.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 1348, 'amount': 810758.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 897, 'amount': 651040.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 3464, 'amount': 2203761.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1190, 'amount': 572976.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1534, 'amount': 794053.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1165, 'amount': 631876.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1390, 'amount': 906282.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1092, 'amount': 500768.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 1727, 'amount': 1168506.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2570, 'amount': 1620649.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 2311, 'amount': 1222782.0}]}]}, 'responseTimestamp': 1692610905345}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 1937, 'amount': 1065604.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 854, 'amount': 588769.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 1323, 'amount': 714947.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 781, 'amount': 526804.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 4006, 'amount': 2403199.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1182, 'amount': 585354.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1264, 'amount': 621128.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1265, 'amount': 729565.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1460, 'amount': 850251.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1270, 'amount': 508161.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 1629, 'amount': 1058050.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2412, 'amount': 1398326.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 2722, 'amount': 1699716.0}]}]}, 'responseTimestamp': 1692610957068}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 2343, 'amount': 1695121.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 842, 'amount': 755796.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 1817, 'amount': 1245872.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 815, 'amount': 702006.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 4655, 'amount': 3497573.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 5308, 'amount': 2719134.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1631, 'amount': 1284850.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1404, 'amount': 1026195.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 4170, 'amount': 2327122.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1410, 'amount': 941389.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2392, 'amount': 1839579.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2967, 'amount': 2201793.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 3451, 'amount': 2494257.0}]}]}, 'responseTimestamp': 1692611009087}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 2248, 'amount': 2073825.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 798, 'amount': 803258.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 1486, 'amount': 1161025.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 736, 'amount': 628946.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 4044, 'amount': 3191769.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1050, 'amount': 877683.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1329, 'amount': 1311735.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1137, 'amount': 1033282.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1452, 'amount': 1216098.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1027, 'amount': 796678.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 1991, 'amount': 1995617.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2519, 'amount': 2102143.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 3258, 'amount': 2722279.0}]}]}, 'responseTimestamp': 1692611061458}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 2532, 'amount': 3543718.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1116, 'amount': 1152210.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2369, 'amount': 2345876.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 924, 'amount': 916336.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 4176, 'amount': 5425896.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1181, 'amount': 1328774.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1322, 'amount': 2101400.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1449, 'amount': 1479933.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1262, 'amount': 1853561.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 910, 'amount': 1306288.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2444, 'amount': 3100521.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2709, 'amount': 3214794.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 3029, 'amount': 3841028.0}]}]}, 'responseTimestamp': 1692611113013}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 3605, 'amount': 5199664.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1004, 'amount': 1393633.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 1878, 'amount': 2608475.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 949, 'amount': 1344329.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 5196, 'amount': 6953446.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1797, 'amount': 2181402.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1551, 'amount': 2556602.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1439, 'amount': 2086496.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 1991, 'amount': 3109555.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 995, 'amount': 1641988.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2887, 'amount': 4304499.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 2748, 'amount': 3988284.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 3914, 'amount': 5279784.0}]}]}, 'responseTimestamp': 1692611164387}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 3103, 'amount': 3899091.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 946, 'amount': 1282760.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2063, 'amount': 2686947.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1145, 'amount': 1412957.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 5851, 'amount': 7046107.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1962, 'amount': 2331922.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1794, 'amount': 2729962.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1418, 'amount': 1920103.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2141, 'amount': 2903957.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1233, 'amount': 1573534.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 2836, 'amount': 4207850.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 3115, 'amount': 3979873.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 4578, 'amount': 5733009.0}]}]}, 'responseTimestamp': 1692611215864}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4355, 'amount': 5505134.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1079, 'amount': 1444643.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2593, 'amount': 3257610.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1270, 'amount': 1573445.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 6720, 'amount': 7779967.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 2137, 'amount': 2552054.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1934, 'amount': 2719786.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1892, 'amount': 2559169.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2314, 'amount': 3113617.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1318, 'amount': 1720753.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3729, 'amount': 5145111.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4431, 'amount': 5271211.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5529, 'amount': 6149431.0}]}]}, 'responseTimestamp': 1692611267351}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4450, 'amount': 5856052.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1294, 'amount': 1623449.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2733, 'amount': 3658896.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1373, 'amount': 1680979.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 7636, 'amount': 9911879.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 2400, 'amount': 2848596.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2425, 'amount': 3710468.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 2261, 'amount': 2993022.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2623, 'amount': 3513389.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1810, 'amount': 2859172.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 4641, 'amount': 6166050.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 5199, 'amount': 6244165.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5484, 'amount': 6977122.0}]}]}, 'responseTimestamp': 1692611319166}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4069, 'amount': 5915626.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1100, 'amount': 1628429.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2461, 'amount': 3621734.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1104, 'amount': 1619607.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 6752, 'amount': 9502319.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1437, 'amount': 2188369.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1565, 'amount': 2882540.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1509, 'amount': 2235497.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2196, 'amount': 3370241.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1208, 'amount': 2088411.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3284, 'amount': 5677174.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 3542, 'amount': 4957590.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 4693, 'amount': 6275818.0}]}]}, 'responseTimestamp': 1692619164140}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 3690, 'amount': 5519480.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1083, 'amount': 1556225.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2468, 'amount': 3679371.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1227, 'amount': 1530183.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 7000, 'amount': 8910217.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1311, 'amount': 1880405.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1688, 'amount': 3027497.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1652, 'amount': 2426306.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2140, 'amount': 3383512.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1473, 'amount': 2483871.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3756, 'amount': 5988173.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 3725, 'amount': 5015442.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5163, 'amount': 6666796.0}]}]}, 'responseTimestamp': 1692619346071}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4157, 'amount': 5720660.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1308, 'amount': 1724487.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 3082, 'amount': 3962298.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1274, 'amount': 1526422.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 8972, 'amount': 11107138.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1695, 'amount': 2170370.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 1947, 'amount': 3392196.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1900, 'amount': 2732465.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2308, 'amount': 3162591.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1723, 'amount': 2310997.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 3993, 'amount': 6350318.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4604, 'amount': 5810698.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 6187, 'amount': 7831756.0}]}]}, 'responseTimestamp': 1697612180991}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'east godavari district', 'metric': [{'type': 'TOTAL', 'count': 4294, 'amount': 6404501.0}]}, {'name': 'srikakulam district', 'metric': [{'type': 'TOTAL', 'count': 1327, 'amount': 1851290.0}]}, {'name': 'spsr nellore district', 'metric': [{'type': 'TOTAL', 'count': 2739, 'amount': 3968074.0}]}, {'name': 'vizianagaram district', 'metric': [{'type': 'TOTAL', 'count': 1350, 'amount': 1745449.0}]}, {'name': 'visakhapatnam district', 'metric': [{'type': 'TOTAL', 'count': 8787, 'amount': 12027284.0}]}, {'name': 'prakasam district', 'metric': [{'type': 'TOTAL', 'count': 1561, 'amount': 2357325.0}]}, {'name': 'anantapur district', 'metric': [{'type': 'TOTAL', 'count': 2143, 'amount': 3651525.0}]}, {'name': 'ysr district', 'metric': [{'type': 'TOTAL', 'count': 1923, 'amount': 2738253.0}]}, {'name': 'west godavari district', 'metric': [{'type': 'TOTAL', 'count': 2198, 'amount': 3630998.0}]}, {'name': 'kurnool district', 'metric': [{'type': 'TOTAL', 'count': 1829, 'amount': 3161720.0}]}, {'name': 'chittoor district', 'metric': [{'type': 'TOTAL', 'count': 4025, 'amount': 7322967.0}]}, {'name': 'guntur district', 'metric': [{'type': 'TOTAL', 'count': 4354, 'amount': 6154821.0}]}, {'name': 'krishna district', 'metric': [{'type': 'TOTAL', 'count': 5268, 'amount': 7328216.0}]}]}, 'responseTimestamp': 1706092837555}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 513.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 513.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 231.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 1124.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 298.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 469.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 1026.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 282.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 827.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 231.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 33, 'amount': 6304.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 9, 'amount': 2511.0}]}]}, 'responseTimestamp': 1692610837813}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 843.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 662.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 166.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 2052.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 166.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 281.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 939.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 60, 'amount': 15776.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 184.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 662.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 364.0}]}, {'name': 'dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 66.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 12, 'amount': 3466.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 9675.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 66.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 695.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 9, 'amount': 1557.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 548.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 33.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 1486.0}]}]}, 'responseTimestamp': 1692610890774}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 9, 'amount': 1981.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 32.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 162.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 1561.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 48, 'amount': 21298.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 691.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 33.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 5505.0}]}, {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1017.0}]}, {'name': 'dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 2967.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 22182.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 8075.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1154.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 32.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 4148.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 2685.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 9740.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 984.0}]}]}, 'responseTimestamp': 1692610942824}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 4680.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 5103.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1334.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 3690.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 167.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 900.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 7696.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 65, 'amount': 62651.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 136.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 733.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 366.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 12, 'amount': 4524.0}]}, {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 415.0}]}, {'name': 'dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 669.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 9871.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 18, 'amount': 8695.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 4237.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 132.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 2951.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1258.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 10155.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 8, 'amount': 1248.0}]}]}, 'responseTimestamp': 1692610994820}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 8091.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 4236.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 18, 'amount': 8990.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 210.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1405.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 69, 'amount': 89335.0}]}, {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 94.0}]}, {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 19882.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 5423.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 210.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 12, 'amount': 11258.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 20, 'amount': 17896.0}]}, {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 933.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 2979.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 467.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 327.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 16, 'amount': 21096.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 23216.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 8880.0}]}]}, 'responseTimestamp': 1692611047105}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 11845.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 11875.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 21, 'amount': 57300.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1245.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 11455.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 38082.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 50, 'amount': 95368.0}]}, {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1531.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 1927.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 946.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 25894.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 21566.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 23, 'amount': 32914.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2417.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 15097.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 946.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 8, 'amount': 5436.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 35207.0}]}]}, 'responseTimestamp': 1692611098571}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 12440.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 10820.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 4852.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 25308.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 6420.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 37402.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 128, 'amount': 232985.0}]}, {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 4597.0}]}, {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1175.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 7876.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 3130.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 26, 'amount': 59532.0}]}, {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 6980.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 37, 'amount': 61049.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 22841.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 6632.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 4783.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 17, 'amount': 19353.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 22217.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 28772.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 19295.0}]}]}, 'responseTimestamp': 1692611150077}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 17012.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 9, 'amount': 27520.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 18234.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 16731.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 3042.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 98280.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 149, 'amount': 339981.0}]}, {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2907.0}]}, {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 56.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 10551.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 6, 'amount': 16596.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 56.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 41022.0}]}, {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 4537.0}]}, {'name': 'dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 4047.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 36, 'amount': 83342.0}]}, {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1335.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 50073.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 7374.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 56.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 17, 'amount': 33684.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 32299.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 59469.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 25903.0}]}]}, 'responseTimestamp': 1692611201654}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 13, 'amount': 25061.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 7, 'amount': 13328.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 6396.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 24, 'amount': 54485.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 1353.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 7050.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 32728.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 310, 'amount': 752159.0}]}, {'name': 'kurung kumey district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 3224.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 9427.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 4261.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 25, 'amount': 51823.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 47, 'amount': 115575.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 29, 'amount': 107087.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 1295.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 10, 'amount': 17345.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 21, 'amount': 59273.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 2554.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 26, 'amount': 61225.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 34582.0}]}]}, 'responseTimestamp': 1692611253049}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'lower dibang valley district', 'metric': [{'type': 'TOTAL', 'count': 17, 'amount': 26960.0}]}, {'name': 'lower subansiri district', 'metric': [{'type': 'TOTAL', 'count': 11, 'amount': 26683.0}]}, {'name': 'longding district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 9842.0}]}, {'name': 'west siang district', 'metric': [{'type': 'TOTAL', 'count': 16, 'amount': 86941.0}]}, {'name': 'kamle district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 2325.0}]}, {'name': 'upper siang district', 'metric': [{'type': 'TOTAL', 'count': 4, 'amount': 6334.0}]}, {'name': 'tirap district', 'metric': [{'type': 'TOTAL', 'count': 23, 'amount': 54004.0}]}, {'name': 'papum pare district', 'metric': [{'type': 'TOTAL', 'count': 250, 'amount': 590296.0}]}, {'name': 'anjaw district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1758.0}]}, {'name': 'siang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 6421.0}]}, {'name': 'lower siang district', 'metric': [{'type': 'TOTAL', 'count': 3, 'amount': 4229.0}]}, {'name': 'kra daadi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 5626.0}]}, {'name': 'changlang district', 'metric': [{'type': 'TOTAL', 'count': 22, 'amount': 53679.0}]}, {'name': 'pakke kessang district', 'metric': [{'type': 'TOTAL', 'count': 2, 'amount': 2018.0}]}, {'name': 'west kameng district', 'metric': [{'type': 'TOTAL', 'count': 42, 'amount': 118030.0}]}, {'name': 'shi yomi district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 1304.0}]}, {'name': 'east siang district', 'metric': [{'type': 'TOTAL', 'count': 35, 'amount': 54567.0}]}, {'name': 'upper subansiri district', 'metric': [{'type': 'TOTAL', 'count': 1, 'amount': 720.0}]}, {'name': 'east kameng district', 'metric': [{'type': 'TOTAL', 'count': 15, 'amount': 25996.0}]}, {'name': 'lohit district', 'metric': [{'type': 'TOTAL', 'count': 18, 'amount': 45865.0}]}, {'name': 'lepa rada district', 'metric': [{'type': 'TOTAL', 'count': 5, 'amount': 9636.0}]}, {'name': 'tawang district', 'metric': [{'type': 'TOTAL', 'count': 24, 'amount': 112439.0}]}, {'name': 'namsai district', 'metric': [{'type': 'TOTAL', 'count': 14, 'amount': 54631.0}]}]}, 'responseTimestamp': 1692611304777}
# ...
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 3388, 'amount': 4205397.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2079, 'amount': 2560858.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 706, 'amount': 923776.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 66, 'amount': 166573.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1565, 'amount': 1865763.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1733, 'amount': 2279289.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 416, 'amount': 492832.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 817, 'amount': 1146713.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 712, 'amount': 989483.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 8821, 'amount': 10908223.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 935, 'amount': 1170361.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 189, 'amount': 271528.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 3386, 'amount': 3925097.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 2535, 'amount': 3346651.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 8666, 'amount': 9648958.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 955, 'amount': 984582.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 504, 'amount': 698386.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2688, 'amount': 3490145.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 1754, 'amount': 2454885.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 1132, 'amount': 1180155.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1361, 'amount': 1892041.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 1776, 'amount': 2288540.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 1669, 'amount': 2202071.0}]}]}, 'responseTimestamp': 1692611296537}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 3847, 'amount': 4752290.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 1771, 'amount': 2507142.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 749, 'amount': 1102859.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 70, 'amount': 151850.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1530, 'amount': 1926824.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 3569, 'amount': 4249681.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 423, 'amount': 502914.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 889, 'amount': 1365036.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 674, 'amount': 977682.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 10071, 'amount': 13297497.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 872, 'amount': 1276744.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 246, 'amount': 438241.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 3875, 'amount': 4827100.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 2783, 'amount': 3954761.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 9215, 'amount': 10683722.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 986, 'amount': 1145406.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 552, 'amount': 857242.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 3046, 'amount': 4171226.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 1870, 'amount': 2669178.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 1243, 'amount': 1340378.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1643, 'amount': 2298694.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2002, 'amount': 2670979.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2351, 'amount': 3298987.0}]}]}, 'responseTimestamp': 1692611348420}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 3767, 'amount': 5042986.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 1917, 'amount': 2683159.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 870, 'amount': 1297160.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 78, 'amount': 168252.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1786, 'amount': 2550194.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 2443, 'amount': 3304941.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 526, 'amount': 764236.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 1014, 'amount': 1598059.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 675, 'amount': 1063753.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 11211, 'amount': 15232572.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 916, 'amount': 1403579.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 228, 'amount': 309298.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 4051, 'amount': 5337244.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 3076, 'amount': 4353663.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 10117, 'amount': 12593112.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 891, 'amount': 1245950.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 569, 'amount': 854000.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 3264, 'amount': 4547900.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2212, 'amount': 3033002.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 730, 'amount': 1071823.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1836, 'amount': 2581429.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2438, 'amount': 3326078.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2218, 'amount': 3099342.0}]}]}, 'responseTimestamp': 1692619193596}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 3576, 'amount': 4536325.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 1656, 'amount': 2145209.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 730, 'amount': 972395.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 90, 'amount': 208239.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1514, 'amount': 1920157.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1804, 'amount': 2352680.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 426, 'amount': 511789.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 924, 'amount': 1416061.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 542, 'amount': 781984.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 9956, 'amount': 12796714.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 764, 'amount': 1073902.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 208, 'amount': 356756.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 3369, 'amount': 4382040.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 2861, 'amount': 3933669.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 9018, 'amount': 11042108.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 860, 'amount': 1052485.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 537, 'amount': 857285.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2918, 'amount': 3955797.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2021, 'amount': 2682343.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 684, 'amount': 939713.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1498, 'amount': 1993114.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 1799, 'amount': 2468202.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2037, 'amount': 2825313.0}]}]}, 'responseTimestamp': 1692619375045}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 4100, 'amount': 5345416.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2444, 'amount': 3247192.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 916, 'amount': 1333587.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 63, 'amount': 121675.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 1706, 'amount': 2303518.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 2108, 'amount': 3021797.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 433, 'amount': 532754.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 1024, 'amount': 1511512.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 768, 'amount': 1218487.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 11653, 'amount': 15397844.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 957, 'amount': 1267409.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 215, 'amount': 287530.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 3960, 'amount': 4940209.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 3336, 'amount': 4705529.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 10667, 'amount': 12579074.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 925, 'amount': 1174482.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 589, 'amount': 870892.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 3285, 'amount': 4337285.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2037, 'amount': 2869837.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 853, 'amount': 1129904.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 1663, 'amount': 2203067.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2131, 'amount': 2771850.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2298, 'amount': 3188462.0}]}]}, 'responseTimestamp': 1697612220007}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverDataList': [{'name': 'south twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 5415, 'amount': 6996283.0}]}, {'name': 'purba bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 2666, 'amount': 3814764.0}]}, {'name': 'uttar dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 1086, 'amount': 1639258.0}]}, {'name': 'kalimpong district', 'metric': [{'type': 'TOTAL', 'count': 126, 'amount': 301521.0}]}, {'name': 'murshidabad district', 'metric': [{'type': 'TOTAL', 'count': 2371, 'amount': 3017303.0}]}, {'name': 'paschim medinipur district', 'metric': [{'type': 'TOTAL', 'count': 3442, 'amount': 4688055.0}]}, {'name': 'dakshin dinajpur district', 'metric': [{'type': 'TOTAL', 'count': 563, 'amount': 801958.0}]}, {'name': 'jalpaiguri district', 'metric': [{'type': 'TOTAL', 'count': 1331, 'amount': 2021880.0}]}, {'name': 'purulia district', 'metric': [{'type': 'TOTAL', 'count': 976, 'amount': 1408299.0}]}, {'name': 'north twenty four parganas district', 'metric': [{'type': 'TOTAL', 'count': 13483, 'amount': 19211808.0}]}, {'name': 'bankura district', 'metric': [{'type': 'TOTAL', 'count': 1307, 'amount': 1781715.0}]}, {'name': 'jhargram district', 'metric': [{'type': 'TOTAL', 'count': 279, 'amount': 506882.0}]}, {'name': 'howrah district', 'metric': [{'type': 'TOTAL', 'count': 5201, 'amount': 6655473.0}]}, {'name': 'hooghly district', 'metric': [{'type': 'TOTAL', 'count': 4025, 'amount': 5665468.0}]}, {'name': 'kolkata district', 'metric': [{'type': 'TOTAL', 'count': 12306, 'amount': 16022532.0}]}, {'name': 'koch bihar district', 'metric': [{'type': 'TOTAL', 'count': 1171, 'amount': 1553342.0}]}, {'name': 'alipurduar district', 'metric': [{'type': 'TOTAL', 'count': 766, 'amount': 1278792.0}]}, {'name': 'paschim bardhaman district', 'metric': [{'type': 'TOTAL', 'count': 4095, 'amount': 5823988.0}]}, {'name': 'nadia district', 'metric': [{'type': 'TOTAL', 'count': 2786, 'amount': 4012958.0}]}, {'name': 'birbhum district', 'metric': [{'type': 'TOTAL', 'count': 1162, 'amount': 1720043.0}]}, {'name': 'purba medinipur district', 'metric': [{'type': 'TOTAL', 'count': 2507, 'amount': 3400040.0}]}, {'name': 'maldah district', 'metric': [{'type': 'TOTAL', 'count': 2886, 'amount': 3998317.0}]}, {'name': 'darjiling district', 'metric': [{'type': 'TOTAL', 'count': 2762, 'amount': 4044883.0}]}]}, 'responseTimestamp': 1706092874438}

# %%
map_ins.shape
# Out:
# (10828, 6)

# %% [markdown]
# #### df7 top_transaction

# %%
#to extract data from top--->transaction
#This is to direct the path to get the data as states from top---transaction

path_7="C:/Users/Admin/Desktop/myproject/pulse/data/top/transaction/country/india/state/"
top_state_list=os.listdir(path_7)
top_state_list

col_t_trans={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in top_state_list:
    state_path=path_7+state+"/"
    top_year=os.listdir(state_path)
    for year in top_year:
        year_path=state_path+year+"/"
        top_year_list=os.listdir(year_path)
        for j_file in top_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D7=json.load(Data)
            #print(D7)
            for data in D7['data']['pincodes']:
              entityname=data['entityName']
              count=data['metric']['count']
              amount=data['metric']['amount']
              col_t_trans['Pincodes'].append(entityname)
              col_t_trans['Transaction_count'].append(count)
              col_t_trans['Transaction_amount'].append(amount)
              col_t_trans['State'].append(state)
              col_t_trans['Year'].append(year)
              col_t_trans['Quater'].append(int(j_file.strip('.json')))
#Succesfully created a dataframe
top_transaction=pd.DataFrame(col_t_trans)

# %%
top_transaction.shape
# Out:
# (8567, 6)

# %% [markdown]
# #### df8 top_user

# %%
#to extract data from top---->user
#This is to direct the path to get the data as states from top---user

path_8="C:/Users/Admin/Desktop/myproject/pulse/data/top/user/country/india/state/"
top_user_list=os.listdir(path_8)
top_user_list

col_t_u={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Registered_Users':[]}

for state in top_user_list:
    state_path=path_8+state+"/"
    top_year=os.listdir(state_path)
    for year in top_year:
        year_path=state_path+year+"/"
        top_year_list=os.listdir(year_path)
        for j_file in top_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D8=json.load(Data)
            #print(D8)
            try:
                for data in D8['data']['pincodes']:
                    pincodes=data['name']
                    registereduser=data['registeredUsers']                    
                    col_t_u['Pincodes'].append(pincodes)
                    col_t_u['Registered_Users'].append(registereduser)
                    col_t_u['State'].append(state)
                    col_t_u['Year'].append(year)
                    col_t_u['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
#Succesfully created a dataframe
top_user=pd.DataFrame(col_t_u)
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 5846}, {'name': 'north and middle andaman', 'registeredUsers': 632}, {'name': 'nicobars', 'registeredUsers': 262}], 'pincodes': [{'name': '744103', 'registeredUsers': 1608}, {'name': '744101', 'registeredUsers': 1108}, {'name': '744105', 'registeredUsers': 1075}, {'name': '744102', 'registeredUsers': 1006}, {'name': '744104', 'registeredUsers': 272}, {'name': '744202', 'registeredUsers': 237}, {'name': '744112', 'registeredUsers': 215}, {'name': '744301', 'registeredUsers': 207}, {'name': '744107', 'registeredUsers': 196}, {'name': '744211', 'registeredUsers': 156}]}, 'responseTimestamp': 1630501494546}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 8143}, {'name': 'north and middle andaman', 'registeredUsers': 911}, {'name': 'nicobars', 'registeredUsers': 351}], 'pincodes': [{'name': '744103', 'registeredUsers': 2188}, {'name': '744101', 'registeredUsers': 1521}, {'name': '744105', 'registeredUsers': 1492}, {'name': '744102', 'registeredUsers': 1419}, {'name': '744104', 'registeredUsers': 396}, {'name': '744202', 'registeredUsers': 343}, {'name': '744112', 'registeredUsers': 299}, {'name': '744107', 'registeredUsers': 293}, {'name': '744301', 'registeredUsers': 273}, {'name': '744211', 'registeredUsers': 240}]}, 'responseTimestamp': 1630501494939}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 10474}, {'name': 'north and middle andaman', 'registeredUsers': 1208}, {'name': 'nicobars', 'registeredUsers': 467}], 'pincodes': [{'name': '744103', 'registeredUsers': 2741}, {'name': '744101', 'registeredUsers': 1978}, {'name': '744105', 'registeredUsers': 1935}, {'name': '744102', 'registeredUsers': 1803}, {'name': '744104', 'registeredUsers': 507}, {'name': '744202', 'registeredUsers': 446}, {'name': '744112', 'registeredUsers': 388}, {'name': '744107', 'registeredUsers': 384}, {'name': '744301', 'registeredUsers': 372}, {'name': '744211', 'registeredUsers': 327}]}, 'responseTimestamp': 1630501495388}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 13133}, {'name': 'north and middle andaman', 'registeredUsers': 1553}, {'name': 'nicobars', 'registeredUsers': 536}], 'pincodes': [{'name': '744103', 'registeredUsers': 3373}, {'name': '744101', 'registeredUsers': 2498}, {'name': '744105', 'registeredUsers': 2416}, {'name': '744102', 'registeredUsers': 2231}, {'name': '744104', 'registeredUsers': 634}, {'name': '744202', 'registeredUsers': 554}, {'name': '744107', 'registeredUsers': 548}, {'name': '744112', 'registeredUsers': 496}, {'name': '744211', 'registeredUsers': 433}, {'name': '744301', 'registeredUsers': 425}]}, 'responseTimestamp': 1630501495714}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 15961}, {'name': 'north and middle andaman', 'registeredUsers': 2013}, {'name': 'nicobars', 'registeredUsers': 622}], 'pincodes': [{'name': '744103', 'registeredUsers': 4136}, {'name': '744101', 'registeredUsers': 3030}, {'name': '744105', 'registeredUsers': 2994}, {'name': '744102', 'registeredUsers': 2667}, {'name': '744104', 'registeredUsers': 756}, {'name': '744202', 'registeredUsers': 753}, {'name': '744107', 'registeredUsers': 667}, {'name': '744112', 'registeredUsers': 585}, {'name': '744211', 'registeredUsers': 524}, {'name': '744301', 'registeredUsers': 488}]}, 'responseTimestamp': 1630501496432}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 18621}, {'name': 'north and middle andaman', 'registeredUsers': 2417}, {'name': 'nicobars', 'registeredUsers': 693}], 'pincodes': [{'name': '744103', 'registeredUsers': 4748}, {'name': '744101', 'registeredUsers': 3631}, {'name': '744105', 'registeredUsers': 3547}, {'name': '744102', 'registeredUsers': 3008}, {'name': '744202', 'registeredUsers': 885}, {'name': '744104', 'registeredUsers': 878}, {'name': '744107', 'registeredUsers': 787}, {'name': '744112', 'registeredUsers': 672}, {'name': '744211', 'registeredUsers': 633}, {'name': '744301', 'registeredUsers': 534}]}, 'responseTimestamp': 1630501496746}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 20518}, {'name': 'north and middle andaman', 'registeredUsers': 2662}, {'name': 'nicobars', 'registeredUsers': 751}], 'pincodes': [{'name': '744103', 'registeredUsers': 5218}, {'name': '744101', 'registeredUsers': 4026}, {'name': '744105', 'registeredUsers': 3920}, {'name': '744102', 'registeredUsers': 3250}, {'name': '744202', 'registeredUsers': 982}, {'name': '744104', 'registeredUsers': 975}, {'name': '744107', 'registeredUsers': 885}, {'name': '744112', 'registeredUsers': 765}, {'name': '744211', 'registeredUsers': 701}, {'name': '744301', 'registeredUsers': 575}]}, 'responseTimestamp': 1630501497383}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 22202}, {'name': 'north and middle andaman', 'registeredUsers': 2955}, {'name': 'nicobars', 'registeredUsers': 803}], 'pincodes': [{'name': '744103', 'registeredUsers': 5637}, {'name': '744101', 'registeredUsers': 4321}, {'name': '744105', 'registeredUsers': 4277}, {'name': '744102', 'registeredUsers': 3485}, {'name': '744202', 'registeredUsers': 1087}, {'name': '744104', 'registeredUsers': 1062}, {'name': '744107', 'registeredUsers': 953}, {'name': '744112', 'registeredUsers': 812}, {'name': '744211', 'registeredUsers': 783}, {'name': '744301', 'registeredUsers': 611}]}, 'responseTimestamp': 1630501497841}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 24174}, {'name': 'north and middle andaman', 'registeredUsers': 3315}, {'name': 'nicobars', 'registeredUsers': 879}], 'pincodes': [{'name': '744103', 'registeredUsers': 6108}, {'name': '744101', 'registeredUsers': 4689}, {'name': '744105', 'registeredUsers': 4684}, {'name': '744102', 'registeredUsers': 3727}, {'name': '744202', 'registeredUsers': 1216}, {'name': '744104', 'registeredUsers': 1154}, {'name': '744107', 'registeredUsers': 1062}, {'name': '744112', 'registeredUsers': 889}, {'name': '744211', 'registeredUsers': 886}, {'name': '744301', 'registeredUsers': 669}]}, 'responseTimestamp': 1630501498181}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 27626}, {'name': 'north and middle andaman', 'registeredUsers': 4100}, {'name': 'nicobars', 'registeredUsers': 984}], 'pincodes': [{'name': '744103', 'registeredUsers': 6804}, {'name': '744105', 'registeredUsers': 5479}, {'name': '744101', 'registeredUsers': 5365}, {'name': '744102', 'registeredUsers': 4066}, {'name': '744202', 'registeredUsers': 1475}, {'name': '744104', 'registeredUsers': 1333}, {'name': '744107', 'registeredUsers': 1252}, {'name': '744112', 'registeredUsers': 1039}, {'name': '744211', 'registeredUsers': 1036}, {'name': '744205', 'registeredUsers': 806}]}, 'responseTimestamp': 1630501498565}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 34833}, {'name': 'north and middle andaman', 'registeredUsers': 5355}, {'name': 'nicobars', 'registeredUsers': 1147}], 'pincodes': [{'name': '744103', 'registeredUsers': 8318}, {'name': '744105', 'registeredUsers': 7007}, {'name': '744101', 'registeredUsers': 6881}, {'name': '744102', 'registeredUsers': 4919}, {'name': '744202', 'registeredUsers': 1965}, {'name': '744104', 'registeredUsers': 1718}, {'name': '744107', 'registeredUsers': 1710}, {'name': '744112', 'registeredUsers': 1372}, {'name': '744211', 'registeredUsers': 1279}, {'name': '744205', 'registeredUsers': 1008}]}, 'responseTimestamp': 1630501498900}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 43908}, {'name': 'north and middle andaman', 'registeredUsers': 7076}, {'name': 'nicobars', 'registeredUsers': 1412}], 'pincodes': [{'name': '744103', 'registeredUsers': 10408}, {'name': '744105', 'registeredUsers': 8962}, {'name': '744101', 'registeredUsers': 8593}, {'name': '744102', 'registeredUsers': 5882}, {'name': '744202', 'registeredUsers': 2711}, {'name': '744107', 'registeredUsers': 2346}, {'name': '744104', 'registeredUsers': 2167}, {'name': '744112', 'registeredUsers': 1761}, {'name': '744211', 'registeredUsers': 1579}, {'name': '744205', 'registeredUsers': 1346}]}, 'responseTimestamp': 1630501499406}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 48352}, {'name': 'north and middle andaman', 'registeredUsers': 7833}, {'name': 'nicobars', 'registeredUsers': 1573}], 'pincodes': [{'name': '744103', 'registeredUsers': 11416}, {'name': '744105', 'registeredUsers': 9934}, {'name': '744101', 'registeredUsers': 9457}, {'name': '744102', 'registeredUsers': 6395}, {'name': '744202', 'registeredUsers': 3005}, {'name': '744107', 'registeredUsers': 2586}, {'name': '744104', 'registeredUsers': 2383}, {'name': '744112', 'registeredUsers': 1940}, {'name': '744211', 'registeredUsers': 1774}, {'name': '744205', 'registeredUsers': 1505}]}, 'responseTimestamp': 1630501499752}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 51903}, {'name': 'north and middle andaman', 'registeredUsers': 8493}, {'name': 'nicobars', 'registeredUsers': 1699}], 'pincodes': [{'name': '744103', 'registeredUsers': 12268}, {'name': '744105', 'registeredUsers': 10668}, {'name': '744101', 'registeredUsers': 10120}, {'name': '744102', 'registeredUsers': 6837}, {'name': '744202', 'registeredUsers': 3261}, {'name': '744107', 'registeredUsers': 2783}, {'name': '744104', 'registeredUsers': 2573}, {'name': '744112', 'registeredUsers': 2083}, {'name': '744211', 'registeredUsers': 1904}, {'name': '744205', 'registeredUsers': 1626}]}, 'responseTimestamp': 1630501500085}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 55873}, {'name': 'north and middle andaman', 'registeredUsers': 9263}, {'name': 'nicobars', 'registeredUsers': 1846}], 'pincodes': [{'name': '744103', 'registeredUsers': 13198}, {'name': '744105', 'registeredUsers': 11480}, {'name': '744101', 'registeredUsers': 10866}, {'name': '744102', 'registeredUsers': 7313}, {'name': '744202', 'registeredUsers': 3543}, {'name': '744107', 'registeredUsers': 3027}, {'name': '744104', 'registeredUsers': 2777}, {'name': '744112', 'registeredUsers': 2250}, {'name': '744211', 'registeredUsers': 2055}, {'name': '744205', 'registeredUsers': 1771}]}, 'responseTimestamp': 1634575136910}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 59807}, {'name': 'north and middle andaman', 'registeredUsers': 10002}, {'name': 'nicobars', 'registeredUsers': 1971}], 'pincodes': [{'name': '744103', 'registeredUsers': 14127}, {'name': '744105', 'registeredUsers': 12300}, {'name': '744101', 'registeredUsers': 11623}, {'name': '744102', 'registeredUsers': 7813}, {'name': '744202', 'registeredUsers': 3815}, {'name': '744107', 'registeredUsers': 3247}, {'name': '744104', 'registeredUsers': 2962}, {'name': '744112', 'registeredUsers': 2411}, {'name': '744211', 'registeredUsers': 2200}, {'name': '744205', 'registeredUsers': 1902}]}, 'responseTimestamp': 1643295751959}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 63487}, {'name': 'north and middle andaman', 'registeredUsers': 10720}, {'name': 'nicobars', 'registeredUsers': 2081}], 'pincodes': [{'name': '744103', 'registeredUsers': 15011}, {'name': '744105', 'registeredUsers': 13070}, {'name': '744101', 'registeredUsers': 12300}, {'name': '744102', 'registeredUsers': 8271}, {'name': '744202', 'registeredUsers': 4107}, {'name': '744107', 'registeredUsers': 3455}, {'name': '744104', 'registeredUsers': 3146}, {'name': '744112', 'registeredUsers': 2552}, {'name': '744211', 'registeredUsers': 2344}, {'name': '744205', 'registeredUsers': 2034}]}, 'responseTimestamp': 1651127652105}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 66959}, {'name': 'north and middle andaman', 'registeredUsers': 11379}, {'name': 'nicobars', 'registeredUsers': 2192}], 'pincodes': [{'name': '744103', 'registeredUsers': 15799}, {'name': '744105', 'registeredUsers': 13791}, {'name': '744101', 'registeredUsers': 12947}, {'name': '744102', 'registeredUsers': 8709}, {'name': '744202', 'registeredUsers': 4361}, {'name': '744107', 'registeredUsers': 3674}, {'name': '744104', 'registeredUsers': 3319}, {'name': '744112', 'registeredUsers': 2700}, {'name': '744211', 'registeredUsers': 2471}, {'name': '744205', 'registeredUsers': 2162}]}, 'responseTimestamp': 1669732284804}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 70445}, {'name': 'north and middle andaman', 'registeredUsers': 11897}, {'name': 'nicobars', 'registeredUsers': 2300}], 'pincodes': [{'name': '744103', 'registeredUsers': 16666}, {'name': '744105', 'registeredUsers': 14503}, {'name': '744101', 'registeredUsers': 13649}, {'name': '744102', 'registeredUsers': 9148}, {'name': '744202', 'registeredUsers': 4572}, {'name': '744107', 'registeredUsers': 3868}, {'name': '744104', 'registeredUsers': 3493}, {'name': '744112', 'registeredUsers': 2837}, {'name': '744211', 'registeredUsers': 2577}, {'name': '744205', 'registeredUsers': 2268}]}, 'responseTimestamp': 1669732416201}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 73692}, {'name': 'north and middle andaman', 'registeredUsers': 12361}, {'name': 'nicobars', 'registeredUsers': 2389}], 'pincodes': [{'name': '744103', 'registeredUsers': 17406}, {'name': '744105', 'registeredUsers': 15185}, {'name': '744101', 'registeredUsers': 14337}, {'name': '744102', 'registeredUsers': 9591}, {'name': '744202', 'registeredUsers': 4760}, {'name': '744107', 'registeredUsers': 4051}, {'name': '744104', 'registeredUsers': 3647}, {'name': '744112', 'registeredUsers': 2975}, {'name': '744211', 'registeredUsers': 2679}, {'name': '744205', 'registeredUsers': 2358}]}, 'responseTimestamp': 1674558294886}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 77052}, {'name': 'north and middle andaman', 'registeredUsers': 12941}, {'name': 'nicobars', 'registeredUsers': 2491}], 'pincodes': [{'name': '744103', 'registeredUsers': 18209}, {'name': '744105', 'registeredUsers': 15848}, {'name': '744101', 'registeredUsers': 15006}, {'name': '744102', 'registeredUsers': 10033}, {'name': '744202', 'registeredUsers': 4993}, {'name': '744107', 'registeredUsers': 4239}, {'name': '744104', 'registeredUsers': 3795}, {'name': '744112', 'registeredUsers': 3141}, {'name': '744211', 'registeredUsers': 2792}, {'name': '744205', 'registeredUsers': 2480}]}, 'responseTimestamp': 1692619114573}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 80112}, {'name': 'north and middle andaman', 'registeredUsers': 13600}, {'name': 'nicobars', 'registeredUsers': 2617}], 'pincodes': [{'name': '744103', 'registeredUsers': 18944}, {'name': '744105', 'registeredUsers': 16488}, {'name': '744101', 'registeredUsers': 15562}, {'name': '744102', 'registeredUsers': 10387}, {'name': '744202', 'registeredUsers': 5239}, {'name': '744107', 'registeredUsers': 4425}, {'name': '744104', 'registeredUsers': 3937}, {'name': '744112', 'registeredUsers': 3261}, {'name': '744211', 'registeredUsers': 2917}, {'name': '744205', 'registeredUsers': 2605}]}, 'responseTimestamp': 1692619296536}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 83305}, {'name': 'north and middle andaman', 'registeredUsers': 14216}, {'name': 'nicobars', 'registeredUsers': 2734}], 'pincodes': [{'name': '744103', 'registeredUsers': 19673}, {'name': '744105', 'registeredUsers': 17171}, {'name': '744101', 'registeredUsers': 16188}, {'name': '744102', 'registeredUsers': 10799}, {'name': '744202', 'registeredUsers': 5480}, {'name': '744107', 'registeredUsers': 4591}, {'name': '744104', 'registeredUsers': 4082}, {'name': '744112', 'registeredUsers': 3382}, {'name': '744211', 'registeredUsers': 3033}, {'name': '744205', 'registeredUsers': 2716}]}, 'responseTimestamp': 1697612120677}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'south andaman', 'registeredUsers': 86348}, {'name': 'north and middle andaman', 'registeredUsers': 14813}, {'name': 'nicobars', 'registeredUsers': 2817}], 'pincodes': [{'name': '744103', 'registeredUsers': 20431}, {'name': '744105', 'registeredUsers': 17824}, {'name': '744101', 'registeredUsers': 16772}, {'name': '744102', 'registeredUsers': 11155}, {'name': '744202', 'registeredUsers': 5700}, {'name': '744107', 'registeredUsers': 4759}, {'name': '744104', 'registeredUsers': 4224}, {'name': '744112', 'registeredUsers': 3496}, {'name': '744211', 'registeredUsers': 3141}, {'name': '744205', 'registeredUsers': 2822}]}, 'responseTimestamp': 1706092778883}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 497187}, {'name': 'east godavari', 'registeredUsers': 350356}, {'name': 'krishna', 'registeredUsers': 323673}, {'name': 'guntur', 'registeredUsers': 317065}, {'name': 'chittoor', 'registeredUsers': 309541}, {'name': 'anantapur', 'registeredUsers': 241192}, {'name': 'kurnool', 'registeredUsers': 240133}, {'name': 'west godavari', 'registeredUsers': 213335}, {'name': 'spsr nellore', 'registeredUsers': 194475}, {'name': 'prakasam', 'registeredUsers': 189949}], 'pincodes': [{'name': '517501', 'registeredUsers': 39884}, {'name': '530016', 'registeredUsers': 34201}, {'name': '517507', 'registeredUsers': 34111}, {'name': '515001', 'registeredUsers': 31964}, {'name': '516001', 'registeredUsers': 29078}, {'name': '518002', 'registeredUsers': 29043}, {'name': '530026', 'registeredUsers': 26889}, {'name': '516360', 'registeredUsers': 26187}, {'name': '520010', 'registeredUsers': 24397}, {'name': '524002', 'registeredUsers': 23439}]}, 'responseTimestamp': 1630501494546}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 636052}, {'name': 'east godavari', 'registeredUsers': 454398}, {'name': 'krishna', 'registeredUsers': 431965}, {'name': 'guntur', 'registeredUsers': 420326}, {'name': 'chittoor', 'registeredUsers': 414306}, {'name': 'anantapur', 'registeredUsers': 326383}, {'name': 'kurnool', 'registeredUsers': 319313}, {'name': 'west godavari', 'registeredUsers': 282393}, {'name': 'spsr nellore', 'registeredUsers': 261049}, {'name': 'prakasam', 'registeredUsers': 253458}], 'pincodes': [{'name': '517501', 'registeredUsers': 53468}, {'name': '517507', 'registeredUsers': 45241}, {'name': '530016', 'registeredUsers': 43386}, {'name': '515001', 'registeredUsers': 42466}, {'name': '516001', 'registeredUsers': 38402}, {'name': '518002', 'registeredUsers': 37593}, {'name': '516360', 'registeredUsers': 34544}, {'name': '530026', 'registeredUsers': 34126}, {'name': '520010', 'registeredUsers': 31871}, {'name': '524002', 'registeredUsers': 31134}]}, 'responseTimestamp': 1630501494940}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 769096}, {'name': 'east godavari', 'registeredUsers': 558982}, {'name': 'krishna', 'registeredUsers': 537086}, {'name': 'guntur', 'registeredUsers': 518931}, {'name': 'chittoor', 'registeredUsers': 515727}, {'name': 'anantapur', 'registeredUsers': 405855}, {'name': 'kurnool', 'registeredUsers': 394311}, {'name': 'west godavari', 'registeredUsers': 349782}, {'name': 'spsr nellore', 'registeredUsers': 322446}, {'name': 'prakasam', 'registeredUsers': 314899}], 'pincodes': [{'name': '517501', 'registeredUsers': 65157}, {'name': '517507', 'registeredUsers': 54849}, {'name': '530016', 'registeredUsers': 52259}, {'name': '515001', 'registeredUsers': 51449}, {'name': '516001', 'registeredUsers': 46691}, {'name': '518002', 'registeredUsers': 45145}, {'name': '516360', 'registeredUsers': 41963}, {'name': '530026', 'registeredUsers': 40580}, {'name': '520010', 'registeredUsers': 38918}, {'name': '524002', 'registeredUsers': 37559}]}, 'responseTimestamp': 1630501495388}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 978288}, {'name': 'east godavari', 'registeredUsers': 694455}, {'name': 'krishna', 'registeredUsers': 682479}, {'name': 'chittoor', 'registeredUsers': 665280}, {'name': 'guntur', 'registeredUsers': 659552}, {'name': 'anantapur', 'registeredUsers': 510892}, {'name': 'kurnool', 'registeredUsers': 498582}, {'name': 'west godavari', 'registeredUsers': 435668}, {'name': 'spsr nellore', 'registeredUsers': 407495}, {'name': 'prakasam', 'registeredUsers': 394962}], 'pincodes': [{'name': '517501', 'registeredUsers': 82873}, {'name': '517507', 'registeredUsers': 70421}, {'name': '530016', 'registeredUsers': 65549}, {'name': '515001', 'registeredUsers': 63576}, {'name': '516001', 'registeredUsers': 58028}, {'name': '518002', 'registeredUsers': 55735}, {'name': '516360', 'registeredUsers': 52058}, {'name': '530026', 'registeredUsers': 51900}, {'name': '520010', 'registeredUsers': 48991}, {'name': '524002', 'registeredUsers': 46616}]}, 'responseTimestamp': 1630501495872}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1174517}, {'name': 'east godavari', 'registeredUsers': 839277}, {'name': 'krishna', 'registeredUsers': 833694}, {'name': 'chittoor', 'registeredUsers': 812314}, {'name': 'guntur', 'registeredUsers': 802394}, {'name': 'anantapur', 'registeredUsers': 612162}, {'name': 'kurnool', 'registeredUsers': 599422}, {'name': 'west godavari', 'registeredUsers': 523372}, {'name': 'spsr nellore', 'registeredUsers': 491908}, {'name': 'prakasam', 'registeredUsers': 474260}], 'pincodes': [{'name': '517501', 'registeredUsers': 100561}, {'name': '517507', 'registeredUsers': 85980}, {'name': '530016', 'registeredUsers': 77790}, {'name': '515001', 'registeredUsers': 75171}, {'name': '516001', 'registeredUsers': 68514}, {'name': '518002', 'registeredUsers': 66689}, {'name': '530026', 'registeredUsers': 61623}, {'name': '516360', 'registeredUsers': 60798}, {'name': '520010', 'registeredUsers': 59055}, {'name': '524002', 'registeredUsers': 55931}]}, 'responseTimestamp': 1630501496432}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1318740}, {'name': 'krishna', 'registeredUsers': 952300}, {'name': 'east godavari', 'registeredUsers': 945181}, {'name': 'chittoor', 'registeredUsers': 925491}, {'name': 'guntur', 'registeredUsers': 915256}, {'name': 'anantapur', 'registeredUsers': 695114}, {'name': 'kurnool', 'registeredUsers': 680118}, {'name': 'west godavari', 'registeredUsers': 592185}, {'name': 'spsr nellore', 'registeredUsers': 558303}, {'name': 'prakasam', 'registeredUsers': 539462}], 'pincodes': [{'name': '517501', 'registeredUsers': 113033}, {'name': '517507', 'registeredUsers': 97534}, {'name': '530016', 'registeredUsers': 87556}, {'name': '515001', 'registeredUsers': 84157}, {'name': '516001', 'registeredUsers': 76617}, {'name': '518002', 'registeredUsers': 75952}, {'name': '530026', 'registeredUsers': 68283}, {'name': '516360', 'registeredUsers': 66885}, {'name': '520010', 'registeredUsers': 66082}, {'name': '524002', 'registeredUsers': 62933}]}, 'responseTimestamp': 1630501496746}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1460464}, {'name': 'krishna', 'registeredUsers': 1066546}, {'name': 'east godavari', 'registeredUsers': 1057167}, {'name': 'chittoor', 'registeredUsers': 1032733}, {'name': 'guntur', 'registeredUsers': 1026418}, {'name': 'anantapur', 'registeredUsers': 773656}, {'name': 'kurnool', 'registeredUsers': 755024}, {'name': 'west godavari', 'registeredUsers': 662102}, {'name': 'spsr nellore', 'registeredUsers': 619592}, {'name': 'prakasam', 'registeredUsers': 598568}], 'pincodes': [{'name': '517501', 'registeredUsers': 124727}, {'name': '517507', 'registeredUsers': 108199}, {'name': '530016', 'registeredUsers': 97323}, {'name': '515001', 'registeredUsers': 93191}, {'name': '518002', 'registeredUsers': 84918}, {'name': '516001', 'registeredUsers': 84693}, {'name': '530026', 'registeredUsers': 74501}, {'name': '516360', 'registeredUsers': 73267}, {'name': '520010', 'registeredUsers': 72722}, {'name': '524002', 'registeredUsers': 69783}]}, 'responseTimestamp': 1630501497384}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1620235}, {'name': 'krishna', 'registeredUsers': 1199971}, {'name': 'east godavari', 'registeredUsers': 1195228}, {'name': 'guntur', 'registeredUsers': 1158708}, {'name': 'chittoor', 'registeredUsers': 1156351}, {'name': 'anantapur', 'registeredUsers': 873033}, {'name': 'kurnool', 'registeredUsers': 846885}, {'name': 'west godavari', 'registeredUsers': 750078}, {'name': 'spsr nellore', 'registeredUsers': 697154}, {'name': 'prakasam', 'registeredUsers': 673522}], 'pincodes': [{'name': '517501', 'registeredUsers': 136436}, {'name': '517507', 'registeredUsers': 119146}, {'name': '530016', 'registeredUsers': 106404}, {'name': '515001', 'registeredUsers': 102848}, {'name': '516001', 'registeredUsers': 94209}, {'name': '518002', 'registeredUsers': 94193}, {'name': '516360', 'registeredUsers': 81619}, {'name': '530026', 'registeredUsers': 81191}, {'name': '520010', 'registeredUsers': 79453}, {'name': '524002', 'registeredUsers': 77681}]}, 'responseTimestamp': 1630501497843}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1763581}, {'name': 'krishna', 'registeredUsers': 1331602}, {'name': 'east godavari', 'registeredUsers': 1329664}, {'name': 'guntur', 'registeredUsers': 1289678}, {'name': 'chittoor', 'registeredUsers': 1270907}, {'name': 'anantapur', 'registeredUsers': 971850}, {'name': 'kurnool', 'registeredUsers': 936293}, {'name': 'west godavari', 'registeredUsers': 843835}, {'name': 'spsr nellore', 'registeredUsers': 775440}, {'name': 'prakasam', 'registeredUsers': 748655}], 'pincodes': [{'name': '517501', 'registeredUsers': 146823}, {'name': '517507', 'registeredUsers': 129214}, {'name': '530016', 'registeredUsers': 114042}, {'name': '515001', 'registeredUsers': 111359}, {'name': '518002', 'registeredUsers': 102905}, {'name': '516001', 'registeredUsers': 102893}, {'name': '516360', 'registeredUsers': 89774}, {'name': '530026', 'registeredUsers': 87449}, {'name': '524002', 'registeredUsers': 85878}, {'name': '520010', 'registeredUsers': 85779}]}, 'responseTimestamp': 1630501498247}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 1904719}, {'name': 'east godavari', 'registeredUsers': 1459116}, {'name': 'krishna', 'registeredUsers': 1459041}, {'name': 'guntur', 'registeredUsers': 1426271}, {'name': 'chittoor', 'registeredUsers': 1385916}, {'name': 'anantapur', 'registeredUsers': 1076953}, {'name': 'kurnool', 'registeredUsers': 1035093}, {'name': 'west godavari', 'registeredUsers': 944829}, {'name': 'spsr nellore', 'registeredUsers': 854459}, {'name': 'prakasam', 'registeredUsers': 830709}], 'pincodes': [{'name': '517501', 'registeredUsers': 156221}, {'name': '517507', 'registeredUsers': 138735}, {'name': '530016', 'registeredUsers': 120621}, {'name': '515001', 'registeredUsers': 119223}, {'name': '518002', 'registeredUsers': 112673}, {'name': '516001', 'registeredUsers': 111898}, {'name': '516360', 'registeredUsers': 98803}, {'name': '524002', 'registeredUsers': 93834}, {'name': '530026', 'registeredUsers': 93224}, {'name': '520010', 'registeredUsers': 91299}]}, 'responseTimestamp': 1630501498565}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2058346}, {'name': 'east godavari', 'registeredUsers': 1601940}, {'name': 'krishna', 'registeredUsers': 1599289}, {'name': 'guntur', 'registeredUsers': 1567595}, {'name': 'chittoor', 'registeredUsers': 1506503}, {'name': 'anantapur', 'registeredUsers': 1186851}, {'name': 'kurnool', 'registeredUsers': 1132240}, {'name': 'west godavari', 'registeredUsers': 1053674}, {'name': 'spsr nellore', 'registeredUsers': 937176}, {'name': 'prakasam', 'registeredUsers': 915240}], 'pincodes': [{'name': '517501', 'registeredUsers': 166768}, {'name': '517507', 'registeredUsers': 149001}, {'name': '515001', 'registeredUsers': 128227}, {'name': '530016', 'registeredUsers': 128059}, {'name': '518002', 'registeredUsers': 121529}, {'name': '516001', 'registeredUsers': 120997}, {'name': '516360', 'registeredUsers': 108073}, {'name': '524002', 'registeredUsers': 102103}, {'name': '530026', 'registeredUsers': 99754}, {'name': '520010', 'registeredUsers': 97752}]}, 'responseTimestamp': 1630501498903}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2209658}, {'name': 'east godavari', 'registeredUsers': 1746280}, {'name': 'krishna', 'registeredUsers': 1744028}, {'name': 'guntur', 'registeredUsers': 1712940}, {'name': 'chittoor', 'registeredUsers': 1631331}, {'name': 'anantapur', 'registeredUsers': 1295872}, {'name': 'kurnool', 'registeredUsers': 1230466}, {'name': 'west godavari', 'registeredUsers': 1163179}, {'name': 'spsr nellore', 'registeredUsers': 1022944}, {'name': 'prakasam', 'registeredUsers': 999462}], 'pincodes': [{'name': '517501', 'registeredUsers': 178328}, {'name': '517507', 'registeredUsers': 160062}, {'name': '515001', 'registeredUsers': 137945}, {'name': '530016', 'registeredUsers': 136049}, {'name': '518002', 'registeredUsers': 130871}, {'name': '516001', 'registeredUsers': 130500}, {'name': '516360', 'registeredUsers': 117397}, {'name': '524002', 'registeredUsers': 110746}, {'name': '530026', 'registeredUsers': 106320}, {'name': '520010', 'registeredUsers': 104956}]}, 'responseTimestamp': 1630501499407}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2368081}, {'name': 'east godavari', 'registeredUsers': 1878769}, {'name': 'krishna', 'registeredUsers': 1876458}, {'name': 'guntur', 'registeredUsers': 1843237}, {'name': 'chittoor', 'registeredUsers': 1751420}, {'name': 'anantapur', 'registeredUsers': 1394849}, {'name': 'kurnool', 'registeredUsers': 1323411}, {'name': 'west godavari', 'registeredUsers': 1254117}, {'name': 'spsr nellore', 'registeredUsers': 1100541}, {'name': 'prakasam', 'registeredUsers': 1075936}], 'pincodes': [{'name': '517501', 'registeredUsers': 190712}, {'name': '517507', 'registeredUsers': 171417}, {'name': '515001', 'registeredUsers': 147941}, {'name': '530016', 'registeredUsers': 145206}, {'name': '518002', 'registeredUsers': 140153}, {'name': '516001', 'registeredUsers': 139840}, {'name': '516360', 'registeredUsers': 126260}, {'name': '524002', 'registeredUsers': 118730}, {'name': '530026', 'registeredUsers': 113581}, {'name': '520010', 'registeredUsers': 112324}]}, 'responseTimestamp': 1630501499750}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2526830}, {'name': 'east godavari', 'registeredUsers': 2006272}, {'name': 'krishna', 'registeredUsers': 2002662}, {'name': 'guntur', 'registeredUsers': 1968681}, {'name': 'chittoor', 'registeredUsers': 1870723}, {'name': 'anantapur', 'registeredUsers': 1492738}, {'name': 'kurnool', 'registeredUsers': 1415585}, {'name': 'west godavari', 'registeredUsers': 1339377}, {'name': 'spsr nellore', 'registeredUsers': 1176334}, {'name': 'prakasam', 'registeredUsers': 1151232}], 'pincodes': [{'name': '517501', 'registeredUsers': 203005}, {'name': '517507', 'registeredUsers': 182425}, {'name': '515001', 'registeredUsers': 157649}, {'name': '530016', 'registeredUsers': 154509}, {'name': '518002', 'registeredUsers': 149368}, {'name': '516001', 'registeredUsers': 148851}, {'name': '516360', 'registeredUsers': 134622}, {'name': '524002', 'registeredUsers': 126459}, {'name': '530026', 'registeredUsers': 120973}, {'name': '520010', 'registeredUsers': 119561}]}, 'responseTimestamp': 1630501500251}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2707931}, {'name': 'east godavari', 'registeredUsers': 2150622}, {'name': 'krishna', 'registeredUsers': 2145423}, {'name': 'guntur', 'registeredUsers': 2110878}, {'name': 'chittoor', 'registeredUsers': 2007011}, {'name': 'anantapur', 'registeredUsers': 1606735}, {'name': 'kurnool', 'registeredUsers': 1522196}, {'name': 'west godavari', 'registeredUsers': 1436576}, {'name': 'spsr nellore', 'registeredUsers': 1263550}, {'name': 'prakasam', 'registeredUsers': 1239147}], 'pincodes': [{'name': '517501', 'registeredUsers': 216777}, {'name': '517507', 'registeredUsers': 194860}, {'name': '515001', 'registeredUsers': 168654}, {'name': '530016', 'registeredUsers': 164812}, {'name': '518002', 'registeredUsers': 159802}, {'name': '516001', 'registeredUsers': 158891}, {'name': '516360', 'registeredUsers': 144068}, {'name': '524002', 'registeredUsers': 135136}, {'name': '530026', 'registeredUsers': 129270}, {'name': '520010', 'registeredUsers': 127618}]}, 'responseTimestamp': 1634575128585}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 2888774}, {'name': 'east godavari', 'registeredUsers': 2294347}, {'name': 'krishna', 'registeredUsers': 2288148}, {'name': 'guntur', 'registeredUsers': 2252443}, {'name': 'chittoor', 'registeredUsers': 2141818}, {'name': 'anantapur', 'registeredUsers': 1719437}, {'name': 'kurnool', 'registeredUsers': 1628242}, {'name': 'west godavari', 'registeredUsers': 1532898}, {'name': 'spsr nellore', 'registeredUsers': 1349290}, {'name': 'prakasam', 'registeredUsers': 1325728}], 'pincodes': [{'name': '517501', 'registeredUsers': 230688}, {'name': '517507', 'registeredUsers': 207174}, {'name': '515001', 'registeredUsers': 179763}, {'name': '530016', 'registeredUsers': 175300}, {'name': '518002', 'registeredUsers': 170267}, {'name': '516001', 'registeredUsers': 169158}, {'name': '516360', 'registeredUsers': 153381}, {'name': '524002', 'registeredUsers': 143764}, {'name': '530026', 'registeredUsers': 137812}, {'name': '520010', 'registeredUsers': 135719}]}, 'responseTimestamp': 1643295743265}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3061324}, {'name': 'east godavari', 'registeredUsers': 2432305}, {'name': 'krishna', 'registeredUsers': 2423373}, {'name': 'guntur', 'registeredUsers': 2387051}, {'name': 'chittoor', 'registeredUsers': 2270705}, {'name': 'anantapur', 'registeredUsers': 1827094}, {'name': 'kurnool', 'registeredUsers': 1729513}, {'name': 'west godavari', 'registeredUsers': 1626039}, {'name': 'spsr nellore', 'registeredUsers': 1431664}, {'name': 'prakasam', 'registeredUsers': 1408929}], 'pincodes': [{'name': '517501', 'registeredUsers': 243791}, {'name': '517507', 'registeredUsers': 218905}, {'name': '515001', 'registeredUsers': 190203}, {'name': '530016', 'registeredUsers': 185094}, {'name': '518002', 'registeredUsers': 180102}, {'name': '516001', 'registeredUsers': 179007}, {'name': '516360', 'registeredUsers': 162263}, {'name': '524002', 'registeredUsers': 151939}, {'name': '530026', 'registeredUsers': 145842}, {'name': '520010', 'registeredUsers': 143308}]}, 'responseTimestamp': 1651127643360}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3226029}, {'name': 'east godavari', 'registeredUsers': 2564165}, {'name': 'krishna', 'registeredUsers': 2552107}, {'name': 'guntur', 'registeredUsers': 2514794}, {'name': 'chittoor', 'registeredUsers': 2392549}, {'name': 'anantapur', 'registeredUsers': 1928213}, {'name': 'kurnool', 'registeredUsers': 1825280}, {'name': 'west godavari', 'registeredUsers': 1714357}, {'name': 'spsr nellore', 'registeredUsers': 1509927}, {'name': 'prakasam', 'registeredUsers': 1487589}], 'pincodes': [{'name': '517501', 'registeredUsers': 256290}, {'name': '517507', 'registeredUsers': 229983}, {'name': '515001', 'registeredUsers': 200266}, {'name': '530016', 'registeredUsers': 194513}, {'name': '518002', 'registeredUsers': 189505}, {'name': '516001', 'registeredUsers': 188295}, {'name': '516360', 'registeredUsers': 170855}, {'name': '524002', 'registeredUsers': 159834}, {'name': '530026', 'registeredUsers': 153586}, {'name': '520010', 'registeredUsers': 150546}]}, 'responseTimestamp': 1669732275258}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3397514}, {'name': 'east godavari', 'registeredUsers': 2702234}, {'name': 'krishna', 'registeredUsers': 2685215}, {'name': 'guntur', 'registeredUsers': 2647100}, {'name': 'chittoor', 'registeredUsers': 2517657}, {'name': 'anantapur', 'registeredUsers': 2030824}, {'name': 'kurnool', 'registeredUsers': 1924127}, {'name': 'west godavari', 'registeredUsers': 1805967}, {'name': 'spsr nellore', 'registeredUsers': 1588875}, {'name': 'prakasam', 'registeredUsers': 1567520}], 'pincodes': [{'name': '517501', 'registeredUsers': 269370}, {'name': '517507', 'registeredUsers': 241720}, {'name': '515001', 'registeredUsers': 210661}, {'name': '530016', 'registeredUsers': 204230}, {'name': '518002', 'registeredUsers': 199354}, {'name': '516001', 'registeredUsers': 197910}, {'name': '516360', 'registeredUsers': 179806}, {'name': '524002', 'registeredUsers': 168015}, {'name': '530026', 'registeredUsers': 161715}, {'name': '520010', 'registeredUsers': 158071}]}, 'responseTimestamp': 1669732406701}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3566854}, {'name': 'east godavari', 'registeredUsers': 2835087}, {'name': 'krishna', 'registeredUsers': 2813645}, {'name': 'guntur', 'registeredUsers': 2774365}, {'name': 'chittoor', 'registeredUsers': 2636036}, {'name': 'anantapur', 'registeredUsers': 2128066}, {'name': 'kurnool', 'registeredUsers': 2018290}, {'name': 'west godavari', 'registeredUsers': 1893310}, {'name': 'spsr nellore', 'registeredUsers': 1663684}, {'name': 'prakasam', 'registeredUsers': 1642503}], 'pincodes': [{'name': '517501', 'registeredUsers': 282766}, {'name': '517507', 'registeredUsers': 253314}, {'name': '515001', 'registeredUsers': 221328}, {'name': '530016', 'registeredUsers': 214155}, {'name': '518002', 'registeredUsers': 209376}, {'name': '516001', 'registeredUsers': 207725}, {'name': '516360', 'registeredUsers': 188768}, {'name': '524002', 'registeredUsers': 176415}, {'name': '530026', 'registeredUsers': 169957}, {'name': '520010', 'registeredUsers': 165734}]}, 'responseTimestamp': 1674558285671}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3732544}, {'name': 'east godavari', 'registeredUsers': 2965296}, {'name': 'krishna', 'registeredUsers': 2941585}, {'name': 'guntur', 'registeredUsers': 2900895}, {'name': 'chittoor', 'registeredUsers': 2755784}, {'name': 'anantapur', 'registeredUsers': 2228505}, {'name': 'kurnool', 'registeredUsers': 2114023}, {'name': 'west godavari', 'registeredUsers': 1980446}, {'name': 'spsr nellore', 'registeredUsers': 1740294}, {'name': 'prakasam', 'registeredUsers': 1719910}], 'pincodes': [{'name': '517501', 'registeredUsers': 295420}, {'name': '517507', 'registeredUsers': 264456}, {'name': '515001', 'registeredUsers': 231542}, {'name': '530016', 'registeredUsers': 223726}, {'name': '518002', 'registeredUsers': 219100}, {'name': '516001', 'registeredUsers': 217104}, {'name': '516360', 'registeredUsers': 197437}, {'name': '524002', 'registeredUsers': 184419}, {'name': '530026', 'registeredUsers': 177985}, {'name': '520010', 'registeredUsers': 173156}]}, 'responseTimestamp': 1692619106052}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 3877504}, {'name': 'east godavari', 'registeredUsers': 3082893}, {'name': 'krishna', 'registeredUsers': 3054956}, {'name': 'guntur', 'registeredUsers': 3014655}, {'name': 'chittoor', 'registeredUsers': 2865250}, {'name': 'anantapur', 'registeredUsers': 2323796}, {'name': 'kurnool', 'registeredUsers': 2202517}, {'name': 'west godavari', 'registeredUsers': 2059880}, {'name': 'spsr nellore', 'registeredUsers': 1811781}, {'name': 'prakasam', 'registeredUsers': 1792637}], 'pincodes': [{'name': '517501', 'registeredUsers': 306201}, {'name': '517507', 'registeredUsers': 273955}, {'name': '515001', 'registeredUsers': 240176}, {'name': '530016', 'registeredUsers': 231775}, {'name': '518002', 'registeredUsers': 227292}, {'name': '516001', 'registeredUsers': 225126}, {'name': '516360', 'registeredUsers': 204900}, {'name': '524002', 'registeredUsers': 191332}, {'name': '530026', 'registeredUsers': 184561}, {'name': '520001', 'registeredUsers': 179439}]}, 'responseTimestamp': 1692619287285}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 4035323}, {'name': 'east godavari', 'registeredUsers': 3211557}, {'name': 'krishna', 'registeredUsers': 3177643}, {'name': 'guntur', 'registeredUsers': 3137289}, {'name': 'chittoor', 'registeredUsers': 2981337}, {'name': 'anantapur', 'registeredUsers': 2421293}, {'name': 'kurnool', 'registeredUsers': 2295754}, {'name': 'west godavari', 'registeredUsers': 2146530}, {'name': 'spsr nellore', 'registeredUsers': 1887005}, {'name': 'prakasam', 'registeredUsers': 1868997}], 'pincodes': [{'name': '517501', 'registeredUsers': 317981}, {'name': '517507', 'registeredUsers': 284487}, {'name': '515001', 'registeredUsers': 249655}, {'name': '530016', 'registeredUsers': 240480}, {'name': '518002', 'registeredUsers': 236199}, {'name': '516001', 'registeredUsers': 233874}, {'name': '516360', 'registeredUsers': 213165}, {'name': '524002', 'registeredUsers': 198528}, {'name': '530026', 'registeredUsers': 192066}, {'name': '520001', 'registeredUsers': 186511}]}, 'responseTimestamp': 1697612109472}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'visakhapatnam', 'registeredUsers': 4180797}, {'name': 'east godavari', 'registeredUsers': 3329036}, {'name': 'krishna', 'registeredUsers': 3291814}, {'name': 'guntur', 'registeredUsers': 3251121}, {'name': 'chittoor', 'registeredUsers': 3089391}, {'name': 'anantapur', 'registeredUsers': 2512744}, {'name': 'kurnool', 'registeredUsers': 2383042}, {'name': 'west godavari', 'registeredUsers': 2227243}, {'name': 'spsr nellore', 'registeredUsers': 1956706}, {'name': 'prakasam', 'registeredUsers': 1939979}], 'pincodes': [{'name': '517501', 'registeredUsers': 328762}, {'name': '517507', 'registeredUsers': 293894}, {'name': '515001', 'registeredUsers': 258235}, {'name': '530016', 'registeredUsers': 248401}, {'name': '518002', 'registeredUsers': 244371}, {'name': '516001', 'registeredUsers': 242054}, {'name': '516360', 'registeredUsers': 220919}, {'name': '524002', 'registeredUsers': 205559}, {'name': '530026', 'registeredUsers': 198977}, {'name': '520001', 'registeredUsers': 192934}]}, 'responseTimestamp': 1706092768010}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'papum pare', 'registeredUsers': 7649}, {'name': 'west kameng', 'registeredUsers': 2202}, {'name': 'east siang', 'registeredUsers': 1803}, {'name': 'tawang', 'registeredUsers': 1525}, {'name': 'changlang', 'registeredUsers': 1208}, {'name': 'lohit', 'registeredUsers': 1207}, {'name': 'west siang', 'registeredUsers': 846}, {'name': 'namsai', 'registeredUsers': 737}, {'name': 'lower dibang valley', 'registeredUsers': 601}, {'name': 'upper subansiri', 'registeredUsers': 572}], 'pincodes': [{'name': '791110', 'registeredUsers': 2316}, {'name': '791111', 'registeredUsers': 2203}, {'name': '791113', 'registeredUsers': 1475}, {'name': '791102', 'registeredUsers': 1471}, {'name': '790104', 'registeredUsers': 1139}, {'name': '791001', 'registeredUsers': 969}, {'name': '791109', 'registeredUsers': 857}, {'name': '792103', 'registeredUsers': 829}, {'name': '792001', 'registeredUsers': 828}, {'name': '790116', 'registeredUsers': 766}]}, 'responseTimestamp': 1630501494547}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'papum pare', 'registeredUsers': 11418}, {'name': 'west kameng', 'registeredUsers': 3442}, {'name': 'east siang', 'registeredUsers': 2646}, {'name': 'tawang', 'registeredUsers': 2266}, {'name': 'changlang', 'registeredUsers': 2014}, {'name': 'lohit', 'registeredUsers': 1898}, {'name': 'namsai', 'registeredUsers': 1276}, {'name': 'west siang', 'registeredUsers': 1224}, {'name': 'lower dibang valley', 'registeredUsers': 893}, {'name': 'upper subansiri', 'registeredUsers': 883}], 'pincodes': [{'name': '791110', 'registeredUsers': 3488}, {'name': '791111', 'registeredUsers': 3272}, {'name': '791113', 'registeredUsers': 2219}, {'name': '791102', 'registeredUsers': 2212}, {'name': '790104', 'registeredUsers': 1698}, {'name': '792103', 'registeredUsers': 1457}, {'name': '791001', 'registeredUsers': 1421}, {'name': '792001', 'registeredUsers': 1315}, {'name': '791109', 'registeredUsers': 1231}, {'name': '790116', 'registeredUsers': 1213}]}, 'responseTimestamp': 1630501494940}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'papum pare', 'registeredUsers': 16009}, {'name': 'west kameng', 'registeredUsers': 4765}, {'name': 'east siang', 'registeredUsers': 3590}, {'name': 'tawang', 'registeredUsers': 3112}, {'name': 'changlang', 'registeredUsers': 2889}, {'name': 'lohit', 'registeredUsers': 2612}, {'name': 'namsai', 'registeredUsers': 1862}, {'name': 'west siang', 'registeredUsers': 1652}, {'name': 'lower dibang valley', 'registeredUsers': 1286}, {'name': 'tirap', 'registeredUsers': 1226}], 'pincodes': [{'name': '791110', 'registeredUsers': 4872}, {'name': '791111', 'registeredUsers': 4610}, {'name': '791113', 'registeredUsers': 3178}, {'name': '791102', 'registeredUsers': 3077}, {'name': '790104', 'registeredUsers': 2328}, {'name': '792103', 'registeredUsers': 2067}, {'name': '791001', 'registeredUsers': 1907}, {'name': '792001', 'registeredUsers': 1819}, {'name': '790116', 'registeredUsers': 1623}, {'name': '791109', 'registeredUsers': 1612}]}, 'responseTimestamp': 1630501495388}
# ...
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 2321888}, {'name': 'kolkata', 'registeredUsers': 1700474}, {'name': 'south twenty four parganas', 'registeredUsers': 1118649}, {'name': 'murshidabad', 'registeredUsers': 1085899}, {'name': 'hooghly', 'registeredUsers': 977339}, {'name': 'howrah', 'registeredUsers': 875172}, {'name': 'nadia', 'registeredUsers': 832891}, {'name': 'purba medinipur', 'registeredUsers': 824961}, {'name': 'paschim medinipur', 'registeredUsers': 747114}, {'name': 'paschim bardhaman', 'registeredUsers': 688685}], 'pincodes': [{'name': '711101', 'registeredUsers': 100995}, {'name': '700006', 'registeredUsers': 86507}, {'name': '700135', 'registeredUsers': 77035}, {'name': '700156', 'registeredUsers': 72172}, {'name': '700039', 'registeredUsers': 67602}, {'name': '700015', 'registeredUsers': 67402}, {'name': '721101', 'registeredUsers': 65712}, {'name': '742304', 'registeredUsers': 65083}, {'name': '700091', 'registeredUsers': 64738}, {'name': '700150', 'registeredUsers': 63152}]}, 'responseTimestamp': 1630501499750}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 2491076}, {'name': 'kolkata', 'registeredUsers': 1823074}, {'name': 'south twenty four parganas', 'registeredUsers': 1202229}, {'name': 'murshidabad', 'registeredUsers': 1166975}, {'name': 'hooghly', 'registeredUsers': 1046242}, {'name': 'howrah', 'registeredUsers': 940133}, {'name': 'nadia', 'registeredUsers': 893107}, {'name': 'purba medinipur', 'registeredUsers': 884605}, {'name': 'paschim medinipur', 'registeredUsers': 800530}, {'name': 'paschim bardhaman', 'registeredUsers': 738540}], 'pincodes': [{'name': '711101', 'registeredUsers': 108369}, {'name': '700006', 'registeredUsers': 92747}, {'name': '700135', 'registeredUsers': 82532}, {'name': '700156', 'registeredUsers': 77110}, {'name': '700039', 'registeredUsers': 72654}, {'name': '700015', 'registeredUsers': 72429}, {'name': '742304', 'registeredUsers': 70194}, {'name': '721101', 'registeredUsers': 70161}, {'name': '700091', 'registeredUsers': 69142}, {'name': '700150', 'registeredUsers': 67705}]}, 'responseTimestamp': 1630501500085}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 2660664}, {'name': 'kolkata', 'registeredUsers': 1944113}, {'name': 'south twenty four parganas', 'registeredUsers': 1286588}, {'name': 'murshidabad', 'registeredUsers': 1248602}, {'name': 'hooghly', 'registeredUsers': 1117731}, {'name': 'howrah', 'registeredUsers': 1004570}, {'name': 'nadia', 'registeredUsers': 955428}, {'name': 'purba medinipur', 'registeredUsers': 946277}, {'name': 'paschim medinipur', 'registeredUsers': 856640}, {'name': 'paschim bardhaman', 'registeredUsers': 789026}], 'pincodes': [{'name': '711101', 'registeredUsers': 115675}, {'name': '700006', 'registeredUsers': 98918}, {'name': '700135', 'registeredUsers': 88230}, {'name': '700156', 'registeredUsers': 82138}, {'name': '700039', 'registeredUsers': 77544}, {'name': '700015', 'registeredUsers': 77301}, {'name': '742304', 'registeredUsers': 75175}, {'name': '721101', 'registeredUsers': 74818}, {'name': '700091', 'registeredUsers': 73614}, {'name': '700150', 'registeredUsers': 72347}]}, 'responseTimestamp': 1630501500556}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 2852030}, {'name': 'kolkata', 'registeredUsers': 2078360}, {'name': 'south twenty four parganas', 'registeredUsers': 1383020}, {'name': 'murshidabad', 'registeredUsers': 1342984}, {'name': 'hooghly', 'registeredUsers': 1198858}, {'name': 'howrah', 'registeredUsers': 1077467}, {'name': 'nadia', 'registeredUsers': 1026795}, {'name': 'purba medinipur', 'registeredUsers': 1017925}, {'name': 'paschim medinipur', 'registeredUsers': 922218}, {'name': 'purba bardhaman', 'registeredUsers': 847622}], 'pincodes': [{'name': '711101', 'registeredUsers': 123732}, {'name': '700006', 'registeredUsers': 105800}, {'name': '700135', 'registeredUsers': 94553}, {'name': '700156', 'registeredUsers': 87746}, {'name': '700039', 'registeredUsers': 82997}, {'name': '700015', 'registeredUsers': 82658}, {'name': '742304', 'registeredUsers': 80698}, {'name': '721101', 'registeredUsers': 80088}, {'name': '700091', 'registeredUsers': 78602}, {'name': '700150', 'registeredUsers': 77501}]}, 'responseTimestamp': 1634575160251}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3043008}, {'name': 'kolkata', 'registeredUsers': 2213659}, {'name': 'south twenty four parganas', 'registeredUsers': 1477679}, {'name': 'murshidabad', 'registeredUsers': 1435266}, {'name': 'hooghly', 'registeredUsers': 1278850}, {'name': 'howrah', 'registeredUsers': 1150144}, {'name': 'nadia', 'registeredUsers': 1096767}, {'name': 'purba medinipur', 'registeredUsers': 1087362}, {'name': 'paschim medinipur', 'registeredUsers': 985745}, {'name': 'purba bardhaman', 'registeredUsers': 905950}], 'pincodes': [{'name': '711101', 'registeredUsers': 132051}, {'name': '700006', 'registeredUsers': 112681}, {'name': '700135', 'registeredUsers': 100918}, {'name': '700156', 'registeredUsers': 93439}, {'name': '700039', 'registeredUsers': 88546}, {'name': '700015', 'registeredUsers': 88070}, {'name': '742304', 'registeredUsers': 86045}, {'name': '721101', 'registeredUsers': 85333}, {'name': '700091', 'registeredUsers': 83634}, {'name': '700150', 'registeredUsers': 82669}]}, 'responseTimestamp': 1643295775516}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3224459}, {'name': 'kolkata', 'registeredUsers': 2340343}, {'name': 'south twenty four parganas', 'registeredUsers': 1569037}, {'name': 'murshidabad', 'registeredUsers': 1524507}, {'name': 'hooghly', 'registeredUsers': 1356282}, {'name': 'howrah', 'registeredUsers': 1218931}, {'name': 'nadia', 'registeredUsers': 1164783}, {'name': 'purba medinipur', 'registeredUsers': 1155279}, {'name': 'paschim medinipur', 'registeredUsers': 1048100}, {'name': 'purba bardhaman', 'registeredUsers': 962974}], 'pincodes': [{'name': '711101', 'registeredUsers': 139738}, {'name': '700006', 'registeredUsers': 119101}, {'name': '700135', 'registeredUsers': 106987}, {'name': '700156', 'registeredUsers': 98734}, {'name': '700039', 'registeredUsers': 93674}, {'name': '700015', 'registeredUsers': 93175}, {'name': '742304', 'registeredUsers': 91059}, {'name': '721101', 'registeredUsers': 90324}, {'name': '700091', 'registeredUsers': 88432}, {'name': '700150', 'registeredUsers': 87552}]}, 'responseTimestamp': 1651127675998}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3397791}, {'name': 'kolkata', 'registeredUsers': 2461795}, {'name': 'south twenty four parganas', 'registeredUsers': 1655743}, {'name': 'murshidabad', 'registeredUsers': 1608797}, {'name': 'hooghly', 'registeredUsers': 1429378}, {'name': 'howrah', 'registeredUsers': 1285159}, {'name': 'nadia', 'registeredUsers': 1229358}, {'name': 'purba medinipur', 'registeredUsers': 1219530}, {'name': 'paschim medinipur', 'registeredUsers': 1105840}, {'name': 'purba bardhaman', 'registeredUsers': 1016127}], 'pincodes': [{'name': '711101', 'registeredUsers': 147152}, {'name': '700006', 'registeredUsers': 125316}, {'name': '700135', 'registeredUsers': 112749}, {'name': '700156', 'registeredUsers': 103879}, {'name': '700039', 'registeredUsers': 98592}, {'name': '700015', 'registeredUsers': 98087}, {'name': '742304', 'registeredUsers': 95822}, {'name': '721101', 'registeredUsers': 95145}, {'name': '700091', 'registeredUsers': 92988}, {'name': '700150', 'registeredUsers': 92299}]}, 'responseTimestamp': 1669732310426}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3578500}, {'name': 'kolkata', 'registeredUsers': 2588380}, {'name': 'south twenty four parganas', 'registeredUsers': 1745822}, {'name': 'murshidabad', 'registeredUsers': 1696729}, {'name': 'hooghly', 'registeredUsers': 1506412}, {'name': 'howrah', 'registeredUsers': 1354886}, {'name': 'nadia', 'registeredUsers': 1296764}, {'name': 'purba medinipur', 'registeredUsers': 1286641}, {'name': 'paschim medinipur', 'registeredUsers': 1165076}, {'name': 'purba bardhaman', 'registeredUsers': 1070637}], 'pincodes': [{'name': '711101', 'registeredUsers': 154935}, {'name': '700006', 'registeredUsers': 131837}, {'name': '700135', 'registeredUsers': 118831}, {'name': '700156', 'registeredUsers': 109159}, {'name': '700039', 'registeredUsers': 103750}, {'name': '700015', 'registeredUsers': 103268}, {'name': '742304', 'registeredUsers': 100694}, {'name': '721101', 'registeredUsers': 100212}, {'name': '700091', 'registeredUsers': 97621}, {'name': '700150', 'registeredUsers': 97135}]}, 'responseTimestamp': 1669732441576}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3755017}, {'name': 'kolkata', 'registeredUsers': 2716412}, {'name': 'south twenty four parganas', 'registeredUsers': 1828512}, {'name': 'murshidabad', 'registeredUsers': 1778470}, {'name': 'hooghly', 'registeredUsers': 1579023}, {'name': 'howrah', 'registeredUsers': 1422011}, {'name': 'nadia', 'registeredUsers': 1359420}, {'name': 'purba medinipur', 'registeredUsers': 1346908}, {'name': 'paschim medinipur', 'registeredUsers': 1217113}, {'name': 'purba bardhaman', 'registeredUsers': 1119310}], 'pincodes': [{'name': '711101', 'registeredUsers': 162816}, {'name': '700006', 'registeredUsers': 138486}, {'name': '700135', 'registeredUsers': 124707}, {'name': '700156', 'registeredUsers': 114380}, {'name': '700039', 'registeredUsers': 109027}, {'name': '700015', 'registeredUsers': 108457}, {'name': '742304', 'registeredUsers': 105471}, {'name': '721101', 'registeredUsers': 105279}, {'name': '700091', 'registeredUsers': 102363}, {'name': '700150', 'registeredUsers': 101966}]}, 'responseTimestamp': 1674558320388}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 3926974}, {'name': 'kolkata', 'registeredUsers': 2838411}, {'name': 'south twenty four parganas', 'registeredUsers': 1913867}, {'name': 'murshidabad', 'registeredUsers': 1868610}, {'name': 'hooghly', 'registeredUsers': 1651210}, {'name': 'howrah', 'registeredUsers': 1488195}, {'name': 'nadia', 'registeredUsers': 1423179}, {'name': 'purba medinipur', 'registeredUsers': 1409101}, {'name': 'paschim medinipur', 'registeredUsers': 1274166}, {'name': 'purba bardhaman', 'registeredUsers': 1171416}], 'pincodes': [{'name': '711101', 'registeredUsers': 170440}, {'name': '700006', 'registeredUsers': 144816}, {'name': '700135', 'registeredUsers': 130409}, {'name': '700156', 'registeredUsers': 119413}, {'name': '700039', 'registeredUsers': 113983}, {'name': '700015', 'registeredUsers': 113400}, {'name': '742304', 'registeredUsers': 111188}, {'name': '721101', 'registeredUsers': 110111}, {'name': '700091', 'registeredUsers': 106950}, {'name': '700150', 'registeredUsers': 106554}]}, 'responseTimestamp': 1692619138605}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 4079270}, {'name': 'kolkata', 'registeredUsers': 2941189}, {'name': 'south twenty four parganas', 'registeredUsers': 1993465}, {'name': 'murshidabad', 'registeredUsers': 1943677}, {'name': 'hooghly', 'registeredUsers': 1717832}, {'name': 'howrah', 'registeredUsers': 1546777}, {'name': 'nadia', 'registeredUsers': 1482400}, {'name': 'purba medinipur', 'registeredUsers': 1468608}, {'name': 'paschim medinipur', 'registeredUsers': 1328693}, {'name': 'purba bardhaman', 'registeredUsers': 1221383}], 'pincodes': [{'name': '711101', 'registeredUsers': 176861}, {'name': '700006', 'registeredUsers': 150098}, {'name': '700135', 'registeredUsers': 135679}, {'name': '700156', 'registeredUsers': 123670}, {'name': '700039', 'registeredUsers': 118190}, {'name': '700015', 'registeredUsers': 117690}, {'name': '742304', 'registeredUsers': 114746}, {'name': '721101', 'registeredUsers': 114293}, {'name': '700150', 'registeredUsers': 110694}, {'name': '700091', 'registeredUsers': 110637}]}, 'responseTimestamp': 1692619321520}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 4241525}, {'name': 'kolkata', 'registeredUsers': 3053050}, {'name': 'south twenty four parganas', 'registeredUsers': 2074469}, {'name': 'murshidabad', 'registeredUsers': 2023550}, {'name': 'hooghly', 'registeredUsers': 1787671}, {'name': 'howrah', 'registeredUsers': 1608895}, {'name': 'nadia', 'registeredUsers': 1544294}, {'name': 'purba medinipur', 'registeredUsers': 1530289}, {'name': 'paschim medinipur', 'registeredUsers': 1384076}, {'name': 'purba bardhaman', 'registeredUsers': 1272153}], 'pincodes': [{'name': '711101', 'registeredUsers': 183739}, {'name': '700006', 'registeredUsers': 155979}, {'name': '700135', 'registeredUsers': 141013}, {'name': '700156', 'registeredUsers': 128192}, {'name': '700039', 'registeredUsers': 122792}, {'name': '700015', 'registeredUsers': 122316}, {'name': '742304', 'registeredUsers': 119245}, {'name': '721101', 'registeredUsers': 118798}, {'name': '700150', 'registeredUsers': 114987}, {'name': '734006', 'registeredUsers': 113991}]}, 'responseTimestamp': 1697612149739}
# {'success': True, 'code': 'SUCCESS', 'data': {'states': None, 'districts': [{'name': 'north twenty four parganas', 'registeredUsers': 4396190}, {'name': 'kolkata', 'registeredUsers': 3159912}, {'name': 'south twenty four parganas', 'registeredUsers': 2154289}, {'name': 'murshidabad', 'registeredUsers': 2100695}, {'name': 'hooghly', 'registeredUsers': 1855311}, {'name': 'howrah', 'registeredUsers': 1669556}, {'name': 'nadia', 'registeredUsers': 1603527}, {'name': 'purba medinipur', 'registeredUsers': 1589203}, {'name': 'paschim medinipur', 'registeredUsers': 1437662}, {'name': 'purba bardhaman', 'registeredUsers': 1321422}], 'pincodes': [{'name': '711101', 'registeredUsers': 190311}, {'name': '700006', 'registeredUsers': 161415}, {'name': '700135', 'registeredUsers': 146345}, {'name': '700156', 'registeredUsers': 132452}, {'name': '700039', 'registeredUsers': 127254}, {'name': '700015', 'registeredUsers': 126663}, {'name': '742304', 'registeredUsers': 123320}, {'name': '721101', 'registeredUsers': 123088}, {'name': '700150', 'registeredUsers': 119283}, {'name': '700091', 'registeredUsers': 118578}]}, 'responseTimestamp': 1706092808273}

# %%
top_user.shape
# Out:
# (8568, 5)

# %% [markdown]
# #### df9 top_insurance

# %%
#to extract data from top---->insurance
#This is to direct the path to get the data as states from top---insurance

path_9="C:/Users/Admin/Desktop/myproject/pulse/data/top/insurance/country/india/state/"
top_ins_list=os.listdir(path_9)
top_ins_list

col_t_i={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transaction_count':[],"Transaction_amount":[]}

for state in top_ins_list:
    state_path=path_9+state+"/"
    top_year=os.listdir(state_path)
    for year in top_year:
        year_path=state_path+year+"/"
        top_year_list=os.listdir(year_path)
        for j_file in top_year_list:
            j_file_path=year_path+j_file
            mode_of_operation='r'
            Data=open(j_file_path,mode_of_operation)
            D9=json.load(Data)
            #print(D9)
            try:
                for data in D9['data']['pincodes']:
                    entityname=data['entityName']
                    Count=data['metric']['count']
                    amount=data['metric']['amount']
                    col_t_i['Pincodes'].append(entityname)
                    col_t_i['Transaction_count'].append(Count)
                    col_t_i['Transaction_amount'].append(amount)
                    col_t_i['State'].append(state)
                    col_t_i['Year'].append(year)
                    col_t_i['Quater'].append(int(j_file.strip('.json')))
            except:
                 pass
#Succesfully created a dataframe
top_ins=pd.DataFrame(col_t_i)

# %%
top_ins.shape
# Out:
# (5249, 6)

# %% [markdown]
# ### Data manipulations in dataframes

# %%
#performing  data cleaning in dataframes that are created
# agg_insurance['State'].unique()
agg_insurance.State= agg_insurance.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
agg_insurance.State= agg_insurance.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
agg_insurance.State= agg_insurance.State.str.replace('-',' ')
agg_insurance.State= agg_insurance.State.str.title()
agg_insurance
# Out:
#                  State  Year  Quater       Name  Count  Insurance_Amount
# 0    Andaman & Nicobar  2020       2  Insurance      6            1360.0
# 1    Andaman & Nicobar  2020       3  Insurance     41           15380.0
# 2    Andaman & Nicobar  2020       4  Insurance    124          157975.0
# 3    Andaman & Nicobar  2021       1  Insurance    225          244266.0
# 4    Andaman & Nicobar  2021       2  Insurance    137          181504.0
# ..                 ...   ...     ...        ...    ...               ...
# 533        West Bengal  2022       4  Insurance  54277        70466433.0
# 534        West Bengal  2023       1  Insurance  56833        77461732.0
# 535        West Bengal  2023       2  Insurance  49792        65204280.0
# 536        West Bengal  2023       3  Insurance  58131        76359312.0
# 537        West Bengal  2023       4  Insurance  72712       100365562.0
#
# [538 rows x 6 columns]

# %%
#agg_transaction
agg_transaction.State= agg_transaction.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
agg_transaction.State= agg_transaction.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
agg_transaction.State= agg_transaction.State.str.replace('-',' ')
agg_transaction.State= agg_transaction.State.str.title()
agg_transaction
# Out:
#                   State  Year  Quater          Transaction_type  \
# 0     Andaman & Nicobar  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018       1         Merchant payments
# 3     Andaman & Nicobar  2018       1        Financial Services
# 4     Andaman & Nicobar  2018       1                    Others
# ...                 ...   ...     ...                       ...
# 4309        West Bengal  2023       4         Merchant payments
# 4310        West Bengal  2023       4     Peer-to-peer payments
# 4311        West Bengal  2023       4  Recharge & bill payments
# 4312        West Bengal  2023       4        Financial Services
# 4313        West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# 3                    33        1.060142e+04
# 4                   256        1.846899e+05
# ...                 ...                 ...
# 4309          354067997        2.390738e+11
# 4310          317959249        9.641385e+11
# 4311           64920775        4.531943e+10
# 4312             480740        4.590073e+08
# 4313             524477        4.041567e+08
#
# [4314 rows x 6 columns]

# %%
# agg_user
agg_user.State= agg_user.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
agg_user.State= agg_user.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
agg_user.State= agg_user.State.str.replace('-',' ')
agg_user.State= agg_user.State.str.title()
agg_user
# Out:
#                   State  Year  Quater   Brands  Transaction_count  percentage
# 0     Andaman & Nicobar  2018       1   Xiaomi               1665    0.247033
# 1     Andaman & Nicobar  2018       1  Samsung               1445    0.214392
# 2     Andaman & Nicobar  2018       1     Vivo                982    0.145697
# 3     Andaman & Nicobar  2018       1     Oppo                501    0.074332
# 4     Andaman & Nicobar  2018       1  OnePlus                332    0.049258
# ...                 ...   ...     ...      ...                ...         ...
# 6727        West Bengal  2022       1   Lenovo             330017    0.015056
# 6728        West Bengal  2022       1  Infinix             284678    0.012987
# 6729        West Bengal  2022       1     Asus             280347    0.012790
# 6730        West Bengal  2022       1    Apple             277752    0.012671
# 6731        West Bengal  2022       1   Others            2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
#map_insurance
map_ins.State= map_ins.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_ins.State= map_ins.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
map_ins.State= map_ins.State.str.replace('-',' ')
map_ins.State= map_ins.State.str.title()
map_ins
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2020       2             south andaman district
# 1      Andaman & Nicobar  2020       2                  nicobars district
# 2      Andaman & Nicobar  2020       3  north and middle andaman district
# 3      Andaman & Nicobar  2020       3             south andaman district
# 4      Andaman & Nicobar  2020       3                  nicobars district
# ...                  ...   ...     ...                                ...
# 10823        West Bengal  2023       4                     nadia district
# 10824        West Bengal  2023       4                   birbhum district
# 10825        West Bengal  2023       4           purba medinipur district
# 10826        West Bengal  2023       4                    maldah district
# 10827        West Bengal  2023       4                 darjiling district
#
#        Transaction_count  Transaction_amount
# 0                      3               795.0
# 1                      3               565.0
# 2                      1               281.0
# 3                     35             13651.0
# 4                      5              1448.0
# ...                  ...                 ...
# 10823               2786           4012958.0
# 10824               1162           1720043.0
# 10825               2507           3400040.0
# 10826               2886           3998317.0
# 10827               2762           4044883.0
#
# [10828 rows x 6 columns]

# %%
#map_transaction
map_trans.State= map_trans.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_trans.State= map_trans.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
map_trans.State= map_trans.State.str.replace('-',' ')
map_trans.State= map_trans.State.str.title()
map_trans
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 17559        West Bengal  2023       4                     nadia district
# 17560        West Bengal  2023       4                   birbhum district
# 17561        West Bengal  2023       4           purba medinipur district
# 17562        West Bengal  2023       4                    maldah district
# 17563        West Bengal  2023       4                 darjiling district
#
#        Transaction_count  Transaction_amount
# 0                    442        9.316631e+05
# 1                   5688        1.256025e+07
# 2                    528        1.139849e+06
# 3                    825        1.317863e+06
# 4                   9395        2.394824e+07
# ...                  ...                 ...
# 17559           36242432        6.879568e+10
# 17560           20708496        3.690499e+10
# 17561           40572042        7.981990e+10
# 17562           34654950        6.416729e+10
# 17563           16807885        2.793986e+10
#
# [17564 rows x 6 columns]

# %%
#map_user
map_user.State= map_user.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
map_user.State= map_user.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
map_user.State= map_user.State.str.replace('-',' ')
map_user.State= map_user.State.str.title()
map_user
# Out:
#                    State  Year  Quater                          Districts  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 17563        West Bengal  2023       4                     nadia district
# 17564        West Bengal  2023       4                   birbhum district
# 17565        West Bengal  2023       4           purba medinipur district
# 17566        West Bengal  2023       4                    maldah district
# 17567        West Bengal  2023       4                 darjiling district
#
#        Registered_Users  app_opens
# 0                   632          0
# 1                  5846          0
# 2                   262          0
# 3                   911          0
# 4                  8143          0
# ...                 ...        ...
# 17563           1603527   67224546
# 17564           1013025   52281841
# 17565           1589203   69991821
# 17566           1134600   88292475
# 17567            660231   39079247
#
# [17568 rows x 6 columns]

# %%
#top_ins
top_ins.State= top_ins.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_ins.State= top_ins.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
top_ins.State= top_ins.State.str.replace('-',' ')
top_ins.State= top_ins.State.str.title()
top_ins
# Out:
#                   State  Year  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2020       2   744301                  3
# 1     Andaman & Nicobar  2020       2   744104                  2
# 2     Andaman & Nicobar  2020       2   744101                  1
# 3     Andaman & Nicobar  2020       3   744112                  9
# 4     Andaman & Nicobar  2020       3   744105                  7
# ...                 ...   ...     ...      ...                ...
# 5244        West Bengal  2023       4   700135                556
# 5245        West Bengal  2023       4   700091                535
# 5246        West Bengal  2023       4   700015                521
# 5247        West Bengal  2023       4   700059                518
# 5248        West Bengal  2023       4   711102                517
#
#       Transaction_amount
# 0                  565.0
# 1                  513.0
# 2                  282.0
# 3                 3432.0
# 4                 3948.0
# ...                  ...
# 5244            939622.0
# 5245            767163.0
# 5246            683025.0
# 5247            843045.0
# 5248            769517.0
#
# [5249 rows x 6 columns]

# %%
#top_transaction
top_transaction.State= top_transaction.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_transaction.State= top_transaction.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
top_transaction.State= top_transaction.State.str.replace('-',' ')
top_transaction.State= top_transaction.State.str.title()
top_transaction
# Out:
#                   State  Year  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018       1   744101               1622
# 1     Andaman & Nicobar  2018       1   744103               1223
# 2     Andaman & Nicobar  2018       1   744102                969
# 3     Andaman & Nicobar  2018       1   744105                685
# 4     Andaman & Nicobar  2018       1   744104                340
# ...                 ...   ...     ...      ...                ...
# 8562        West Bengal  2023       4   721301            4133775
# 8563        West Bengal  2023       4   700001            3983241
# 8564        West Bengal  2023       4   732125            3950411
# 8565        West Bengal  2023       4   700039            3742452
# 8566        West Bengal  2023       4   700014            3652710
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...                  ...
# 8562        5.718222e+09
# 8563        8.039689e+09
# 8564        6.557345e+09
# 8565        5.608622e+09
# 8566        6.184795e+09
#
# [8567 rows x 6 columns]

# %%
#top_user
top_user.State= top_user.State.str.replace('andaman-&-nicobar-islands','Andaman & Nicobar')
top_user.State= top_user.State.str.replace('Dadra & Nagar Haveli & Daman & Diu','Dadra and Nagar Haveli and Daman and Diu')
top_user.State= top_user.State.str.replace('-',' ')
top_user.State= top_user.State.str.title()
top_user
# Out:
#                   State  Year  Quater Pincodes  Registered_Users
# 0     Andaman & Nicobar  2018       1   744103              1608
# 1     Andaman & Nicobar  2018       1   744101              1108
# 2     Andaman & Nicobar  2018       1   744105              1075
# 3     Andaman & Nicobar  2018       1   744102              1006
# 4     Andaman & Nicobar  2018       1   744104               272
# ...                 ...   ...     ...      ...               ...
# 8563        West Bengal  2023       4   700015            126663
# 8564        West Bengal  2023       4   742304            123320
# 8565        West Bengal  2023       4   721101            123088
# 8566        West Bengal  2023       4   700150            119283
# 8567        West Bengal  2023       4   700091            118578
#
# [8568 rows x 5 columns]

# %%
#creating table in SQL
p_db= psycopg2.connect(host="localhost",
                        user="postgres",
                        password="1234",
                        database="phonepe_pulse_data",
                        port="5432")
cursor= p_db.cursor()


#Table1------->agg_insurance 
create_query='''create table if not exists agg_insurance(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Transaction_type VARCHAR(200),
                                                            Transaction_Count BIGINT,
                                                            Transaction_Amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into agg_insurance(State, Year, Quater, Transaction_type, Transaction_Count, Transaction_Amount )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_agg_insurance=agg_insurance.values.tolist()

cursor.executemany(insert_query,data_from_agg_insurance)
p_db.commit()

# %%
#Table2------->agg_transaction 
create_query='''create table if not exists agg_transaction(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Transaction_type VARCHAR(200),
                                                            Transaction_Count BIGINT,
                                                            Transaction_Amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into agg_transaction(State, Year, Quater, Transaction_type, Transaction_Count, Transaction_Amount )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_agg_transaction=agg_transaction.values.tolist()

cursor.executemany(insert_query,data_from_agg_transaction)
p_db.commit()

# %%
#Table3------->agg_user 
create_query='''create table if not exists agg_user(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Brands VARCHAR(200),
                                                            Transaction_Count BIGINT,
                                                            Percentage FLOAT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into agg_user(State, Year, Quater, Brands, Transaction_Count, Percentage )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_agg_user=agg_user.values.tolist()

cursor.executemany(insert_query,data_from_agg_user)
p_db.commit()

# %%
#Table4------->map_insurance
create_query='''create table if not exists map_insurance(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Districts VARCHAR(200),
                                                            Transaction_Count BIGINT,
                                                            Transaction_amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into map_insurance(State, Year, Quater, Districts, Transaction_Count, Transaction_amount )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_map_insurance=map_ins.values.tolist()

cursor.executemany(insert_query,data_from_map_insurance)
p_db.commit()

# %%
#Table5------->map_transaction
create_query='''create table if not exists map_transaction(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Districts VARCHAR(200),
                                                            Transaction_Count BIGINT,
                                                            Transaction_amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into map_transaction(State, Year, Quater, Districts, Transaction_Count, Transaction_amount )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_map_transaction=map_trans.values.tolist()

cursor.executemany(insert_query,data_from_map_transaction)
p_db.commit()

# %%
#Table6------->map_user
create_query='''create table if not exists map_user(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Districts VARCHAR(200),
                                                            Registered_Users BIGINT,
                                                            app_opens BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into map_user(State, Year, Quater, Districts, Registered_Users, app_opens )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_map_user=map_user.values.tolist()

cursor.executemany(insert_query,data_from_map_user)
p_db.commit()

# %%
#Table7------->top_insurance
create_query='''create table if not exists top_insurance(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Pincodes INT,
                                                            Transaction_Count BIGINT,
                                                            Transaction_amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into top_insurance(State, Year, Quater, Pincodes, Transaction_Count, Transaction_amount )
                    
                    
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_top_insurance=top_ins.values.tolist()

cursor.executemany(insert_query,data_from_top_insurance)
p_db.commit()

# %%
#Table8------->top_transaction
create_query='''create table if not exists top_transaction(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Pincodes INT,
                                                            Transaction_Count BIGINT,
                                                            Transaction_amount BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into top_transaction(State, Year, Quater, Pincodes, Transaction_Count, Transaction_amount )
                    
                                        
                                        values(%s,%s,%s,%s,%s,%s)'''
data_from_top_transaction=top_transaction.values.tolist()

cursor.executemany(insert_query,data_from_top_transaction)
p_db.commit()

# %%
#Table9------->top_user
create_query='''create table if not exists top_user(State VARCHAR(200),
                                                            Year int,
                                                            Quater int,
                                                            Pincodes INT,
                                                            Registered_Users BIGINT
                                                            )'''
cursor.execute(create_query)
p_db.commit()
        
insert_query=''' INSERT into top_user(State, Year, Quater, Pincodes, Registered_Users )
                    
                                        
                                        values(%s,%s,%s,%s,%s)'''
data_from_top_user=top_user.values.tolist()

cursor.executemany(insert_query,data_from_top_user)
p_db.commit()

# %%
#dataframe creation from sql
p_db= psycopg2.connect(host="localhost",
                        user="postgres",
                        password="1234",
                        database="phonepe_pulse_data",
                        port="5432")
cursor= p_db.cursor()

#agg_insurance_df
cursor.execute('select * from agg_insurance')
p_db.commit()
df1=cursor.fetchall()
Aggregate_insurance = pd.DataFrame(df1,columns=('State','Year','Quater','Transaction_Type','Transaction_Count','Transaction_Amount'))
#Aggregate_insurance

#agg_transaction_df
cursor.execute('select * from agg_transaction')
p_db.commit()
df2=cursor.fetchall()
Aggregate_transaction = pd.DataFrame(df2,columns=('State','Year','Quater','Transaction_Type','Transaction_Count','Transaction_Amount'))
#Aggregate_transaction

#agg_user_df
cursor.execute('select * from agg_user')
p_db.commit()
df3=cursor.fetchall()
Aggregate_user = pd.DataFrame(df3,columns=('State','Year','Quater','Brands','Transaction_Count','Percentage'))
#Aggregate_user

#map_insurance_df
cursor.execute('select * from map_insurance')
p_db.commit()
df4=cursor.fetchall()
Map_insurance = pd.DataFrame(df4,columns=('State','Year','Quater','Districts','Transaction_Count','Transaction_Amount'))
#Map_insurance

#map_transaction_df
cursor.execute('select * from map_transaction')
p_db.commit()
df5=cursor.fetchall()
Map_transaction = pd.DataFrame(df5,columns=('State','Year','Quater','Districts','Transaction_Count','Transaction_Amount'))
#Map_transaction

#map_user_df
cursor.execute('select * from map_user')
p_db.commit()
df6=cursor.fetchall()
Map_user = pd.DataFrame(df6,columns=('State','Year','Quater','Districts','Registered_Users','App_Opens'))
#Map_user

#top_insurance_df
cursor.execute('select * from top_insurance')
p_db.commit()
df7=cursor.fetchall()
Top_insurance = pd.DataFrame(df7,columns=('State','Year','Quater','Pincodes','Transaction_Count','Transaction_Amount'))
#Top_insurance

#top_transaction_df
cursor.execute('select * from top_transaction')
p_db.commit()
df8=cursor.fetchall()
Top_transaction = pd.DataFrame(df8,columns=('State','Year','Quater','Pincodes','Transaction_Count','Transaction_Amount'))
#Top_transaction

#top_user_df
cursor.execute('select * from top_user')
p_db.commit()
df9=cursor.fetchall()
Top_user = pd.DataFrame(df9,columns=('State','Year','Quater','Pincodes','Registered_Users'))
Top_user
# Out:
#                    State  Year  Quater  Pincodes  Registered_Users
# 0      Andaman & Nicobar  2018       1    744103              1608
# 1      Andaman & Nicobar  2018       1    744101              1108
# 2      Andaman & Nicobar  2018       1    744105              1075
# 3      Andaman & Nicobar  2018       1    744102              1006
# 4      Andaman & Nicobar  2018       1    744104               272
# ...                  ...   ...     ...       ...               ...
# 17131        West Bengal  2023       4    700015            126663
# 17132        West Bengal  2023       4    742304            123320
# 17133        West Bengal  2023       4    721101            123088
# 17134        West Bengal  2023       4    700150            119283
# 17135        West Bengal  2023       4    700091            118578
#
# [17136 rows x 5 columns]

# %% [markdown]
# #### List of Tables

# %%
Aggregate_insurance
Aggregate_transaction
Aggregate_user

Map_insurance
Map_transaction
Map_user

Top_insurance
Top_transaction
Top_user
# Out:
#                    State  Year  Quater  Pincodes  Registered_Users
# 0      Andaman & Nicobar  2018       1    744103              1608
# 1      Andaman & Nicobar  2018       1    744101              1108
# 2      Andaman & Nicobar  2018       1    744105              1075
# 3      Andaman & Nicobar  2018       1    744102              1006
# 4      Andaman & Nicobar  2018       1    744104               272
# ...                  ...   ...     ...       ...               ...
# 17131        West Bengal  2023       4    700015            126663
# 17132        West Bengal  2023       4    742304            123320
# 17133        West Bengal  2023       4    721101            123088
# 17134        West Bengal  2023       4    700150            119283
# 17135        West Bengal  2023       4    700091            118578
#
# [17136 rows x 5 columns]
